# %% [markdown]
# <div style="width: 100%; clear: both;">
# <div style="float: left; width: 50%;">
# <img src="http://www.uoc.edu/portal/_resources/common/imatges/marca_UOC/UOC_Masterbrand.jpg", align="left">
# </div>
# <div style="float: right; width: 50%;">
# <p style="margin: 0; padding-top: 22px; text-align:right;">M2.975 · Deep Learning</p>
# <p style="margin: 0; text-align:right;">2021-2 · Màster universitari en Ciència de dades (Data science)</p>
# <p style="margin: 0; text-align:right; padding-button: 100px;">Estudis d'Informàtica, Multimèdia i Telecomunicació</p>
# </div>
# </div>
# <div style="width:100%;">&nbsp;</div>
#
#
# # Pràctica: Glaucoma

# %% [markdown]
# ## Secció 1. Anàlisi Exploratòria de les dades (1,5 punts)
# Segons l'article, el conjunt de dades està format per 1707 imatges de 224x224 píxels i repartides en 10 folds. El primer pas serà doncs obtenir el dataset per i comprovar que tenim les dades esperades.
#
# Addicionalment, ens plantegem les següents preguntes sobre el dataset:
#
# * Quin tipus de cross validation tenim?
# * Estan estratificats els k-folds

# %% [markdown]
# ### Generació del dataset
# Carreguem les llibreries i llegim les imatges

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import warnings
import os
import matplotlib.pyplot as plt
import cv2
from random import randint 
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.optimizers import Adam
import timeit
from sklearn.utils import shuffle
import tensorflow as tf
from sklearn.metrics import confusion_matrix, classification_report, recall_score, precision_score, f1_score
import tensorflow_addons as tfa
import seaborn as sn
from keras.callbacks import ModelCheckpoint, EarlyStopping
from datetime import datetime
from keras.models import load_model


# variable global d'entorn de test
localEnv = False
deltaZero = 0.0000001
if (localEnv):
    deltaZero = 0.0000001 # Avoid divide by zero on local mode

# Folder execució
execFolder = "EX_%s" % datetime.today().strftime('%Y%m%d_%H%M%S')

# Flag dels models ha generar
flags_gridsearch = [True, True, True, True, True]
flags_model = [True, True, True, True, True]

# verbose fit
verboseFit = 0

# %%
# Imatges
images = []
filenames = []
classes = []

# Dataset
data_aux = []

# Recorrem totes les imatges
for dirname, _, dirfilenames in os.walk('/kaggle/input'):
    dirname = dirname.replace("\\","/")
    for filename in dirfilenames:
        folders = dirname.split(sep="/")
        
        # Generem un diccionari amb les imatges pre evitar llegir-les cada vegada
        if (filename not in filenames):
            # load the image with load_img
            #img = load_img(dirname+"/"+filename)
            
            # load the image with cv2 (color)
            img = cv2.cvtColor(cv2.imread(dirname+"/"+filename, -1), cv2.COLOR_BGR2RGB)
            
            filenames.append(filename)
            images.append(img)
            classes.append(folders[len(folders)-1])
        
        

        data_aux.append(
                        {
                            'image':filename,
                            'fold': folders[len(folders)-3],
                            'dataset': folders[len(folders)-2],
                            'class': folders[len(folders)-1]
                        }
                    )

df_data = pd.DataFrame(data_aux)
images = np.array(images)
classes = np.array(classes)
filenames = np.array(filenames)
dict_images = dict(zip(filenames, images))

# Mostrem 10 imatges aleatòries
sample = [(randint(1, len(images))) for i in range(10)]
fig, axis = plt.subplots(2, 5, figsize=(10,5))
for i, (X, ax, y) in enumerate(zip(images, axis.reshape(-1), filenames)):
    img = images[sample[i]]
    ax.imshow(img)
    ax.axis('off')
    ax.set_title(filenames[sample[i]]+"\n"+classes[sample[i]])

# %%
# Anàlisi del conjunt de dades descarregat
#Shapes
print("Dimensions de cada imatge (%s)" % (','.join(str(x) for x in img.shape)))
print("Número d'imatges diferents (%s)" % (','.join(str(x) for x in filenames.shape)))
print("Imatges usades en la validació creuada (%s)" % (','.join(str(x) for x in df_data.shape)))
# Out:
# Dimensions de cada imatge (224,224,3)
# Número d'imatges diferents (1707)
# Imatges usades en la validació creuada (17070,4)

# %% [markdown]
# A partir de les dimensions de les dades deduïm que cada fold conté totes les imatges de manera que per l'anàlisi exploratori de les dades carregarem només les dades del Fold0.

# %% [markdown]
# #### Revisió dels folds
# A partir de l'estructura de directoris hem obtingut la classe, el fold al que pertany i a quin conjunt de dades pertany la imatge (train, test, valid) dins del fold. Comprovem com es distribueixen les dades per cada fold.

# %%
df_data = pd.DataFrame(data_aux)

fig, ax = plt.subplots(nrows=2, ncols=5, figsize=(15,10))
plot_num = 1
for i in range(10):
    fold = ("Fold%d") % i
    data_i = df_data[df_data.fold == fold]
    plt.subplot(2,5, plot_num)
    plt.title(("Distribució  %s") % fold)
    plt.hist(data_i["class"],alpha=0.5, label="class")
    plot_num += 1   

plt.tight_layout()

# %% [markdown]
# Cada fold té una distribució de classes (normal i abnormal) igual de manera que sembla que sí estan estratificats. Fem el al mateix per als datasets per descartar que hi hagi folds amb més o menys dades per a test a validació.

# %%
# Agreguem les dades per pintar les barres
grouped_data = df_data.groupby(
    ['fold', 'dataset','class']
).size().sort_values(ascending=False).reset_index(name='count') 

# Pintem el gràfic
fig, axs = plt.subplots(nrows=2, ncols=5, figsize=(25,10))

i = 0
for n in range(2):
    for m in range(5):
        # Tractem cada fold
        fold = ("Fold%d") % i
        grouped_data_i = grouped_data[grouped_data.fold == fold]

        ax=axs[n,m]
        x = np.arange(len(grouped_data_i.dataset.unique()))
        bar_width = 0.4
        b1 = ax.bar(x, grouped_data_i.loc[grouped_data_i['class'] == 'normal', 'count'],
                    width=bar_width, label = "normal")
        b2 = ax.bar(x + bar_width, grouped_data_i.loc[grouped_data_i['class'] == 'abnormal', 'count'],
                    width=bar_width, label = "abnormal")

        # Fix the x-axes.
        ax.set_xticks(x + bar_width / 2)
        ax.set_xticklabels(grouped_data_i.dataset.unique())
        ax.legend()

        # Add axis and chart labels.
        ax.set_xlabel('Dataset', labelpad=15)
        ax.set_ylabel('# imatges', labelpad=15)
        ax.set_title('Imatges de cada classe per dataset dins del %s' % fold, pad=15)
        i += 1   

plt.tight_layout()

# %% [markdown]
# Observem que tots els folds tenen la mateixa distribució de casos i mides semblants per a cada dataset (train, test, valid) i classe (normal, abnormal). Podem dir que no tenim folds amb biaix. Ens queda per comprovar com s'han fet els folds.
#
# Per acabar mirem si les dades estan repartides de forma equitativa. És a dir, quina estatègia de repartició hi ha al darrera. Per a una estratègia de K-fold cross validation hom esperaria que totes les dades es fessin servir per entrenar i testejar el model i que el conjunt de validació fos sempre el mateix ja que haurien de ser dades que no s'hagin usat mai durant la generació del model (ni entrenament, ni test)<sup>1</sup>
#
# Per tant, esperaríem que les dades de validació sempre fossin les mateixes i la resta es dividissin en 10 grups amb la mateixa distribució de classes on cada grup es fes servir a 9 folds per a entrenament i 1 cop per a test.
#
# Veiem a la taula següent com això no és així i no som capaços d'identificar grups de tamany similar. Sobta veure que hi ha moltes dades que només s'han fet servir per a entrenar i no per a validar o testejar (Grups 8 i 9).
#
# <div style="font-size: 12px;">
#
# | Id Grup	|class	|Fold0.dataset	|Fold1.dataset	|Fold2.dataset	|Fold3.dataset	|Fold4.dataset	|Fold5.dataset	|Fold6.dataset	|Fold7.dataset	|Fold8.dataset	|Fold9.dataset	|Count	|
# |---	|---	|---	|---	|---	|---	|---	|---	|---	|---	|---	|---	|---	|
# |Grup1	|normal	|test	|test	|test	|test	|test	|test	|test	|test	|test	|test	|5	|
# |Grup2	|abnormal	|test	|train	|train	|train	|train	|train	|train	|train	|train	|train	|77	|
# |Grup3	|normal	|test	|train	|train	|train	|train	|train	|train	|train	|train	|train	|76	|
# |Grup4	|abnormal	|test	|valid	|valid	|valid	|valid	|valid	|valid	|valid	|valid	|valid	|4	|
# |Grup5	|normal	|test	|valid	|valid	|valid	|valid	|valid	|valid	|valid	|valid	|valid	|1	|
# |Grup6	|abnormal	|train	|test	|test	|test	|test	|test	|test	|test	|test	|test	|70	|
# |Grup7	|normal	|train	|test	|test	|test	|test	|test	|test	|test	|test	|test	|77	|
# |Grup8	|abnormal	|train	|train	|train	|train	|train	|train	|train	|train	|train	|train	|499	|
# |Grup9	|normal	|train	|train	|train	|train	|train	|train	|train	|train	|train	|train	|600	|
# |Grup10	|abnormal	|train	|valid	|valid	|valid	|valid	|valid	|valid	|valid	|valid	|valid	|56	|
# |Grup11	|normal	|train	|valid	|valid	|valid	|valid	|valid	|valid	|valid	|valid	|valid	|77	|
# |Grup12	|abnormal	|valid	|test	|test	|test	|test	|test	|test	|test	|test	|test	|2	|
# |Grup13	|normal	|valid	|test	|test	|test	|test	|test	|test	|test	|test	|test	|9	|
# |Grup14	|abnormal	|valid	|train	|train	|train	|train	|train	|train	|train	|train	|train	|63	|
# |Grup15	|normal	|valid	|train	|train	|train	|train	|train	|train	|train	|train	|train	|64	|
# |Grup16	|abnormal	|valid	|valid	|valid	|valid	|valid	|valid	|valid	|valid	|valid	|valid	|6	|
# |Grup17	|normal	|valid	|valid	|valid	|valid	|valid	|valid	|valid	|valid	|valid	|valid	|10	|
# </div>
# <p><sup>1</sup> Gironés Roig, Jordi; Casas Roma, Jordi; Minguillón Alfonso, Julià; Cahiluelas Quiles, Ramon. Minería de Datos. Modelos y Algoritmos. Barcelona: Editorial UOC, 2017. ISBN: 978-84-9116-904-8 [consulta: 28 de maig de 2022]

# %% [markdown]
# ## Secció 2. Entrenament d’una xarxa neuronal sobre una única partició (4 punts)
# A continuació entrenarem 5 models diferents a partir de les dades anteriors sobre la partició Fold0 la qual ja hem comprovat a l’apartat anterior que tenia una distribució d’imatges semblant al conjunt de dades.
# Els 3 primers models es basaran en basat en EfficientNet  B0 preentrenats amb els pesos d'ImageNet  . Per a generar el model farem servir la llibreria Keras  .
# Donat que el volum de dades és relativament baix i la similitud de les imatges molt gran ens decantarem per aprofitar les primeres capes d’EfficientNet congelant-les. D’aquesta manera aprofitarem la potència d’EfficientNet per extreure característiques de les imatges que posteriorment el nostre model aprofitarà per aprendre i classificar les imatges del nostre model.

# %% [markdown]
# ### Model 1
# Model basat en EfficientNet B0, preentrenat amb els pesos d'Imagenet, al qual se substitueix la seva capa de classificació per: una capa de GlobalAveragePolling2D, una capa de BatchNormalization, una capa de dropout amb probabilitat del 20%, i finalment una capa fully connected.

# %% [markdown]
# Abans generarem una funció per a obtenir els jocs de dades per a entrenar a partir del fold.

# %%
def getData (fold):
    # Obtenim les dades del fold
    df_fold_data = df_data[df_data.fold==fold]

    # Recorrem les dades i generem els diferents arrays
    X_train_fold = []
    X_test_fold = []
    X_valid_fold = []
    y_train_fold = []
    y_test_fold = []
    y_valid_fold = []

    for index, row in df_fold_data.iterrows():
        # Convertim l'array de string en nombre.
        #  0 -> Normal
        #  1 -> Abnormal
        y = 0 if row["class"] == 'normal' else 1 

        if row['dataset']=="train":
            # Add to train
            X_train_fold.append(dict_images[row["image"]])
            y_train_fold.append(y)

        elif row['dataset']=="test":
            # Add to test
            X_test_fold.append(dict_images[row["image"]])
            y_test_fold.append(y)

        else:
            # Add to validate
            X_valid_fold.append(dict_images[row["image"]])
            y_valid_fold.append(y)

    # Desendrecem les dades
    p_train = np.random.permutation(len(X_train_fold))
    p_test = np.random.permutation(len(X_test_fold))
    p_valid = np.random.permutation(len(X_valid_fold))
    
    # Retornem els resultats
    return  np.array(X_train_fold)[p_train], np.array(y_train_fold)[p_train], np.array(X_test_fold)[p_test], np.array(y_test_fold)[p_test], np.array(X_valid_fold)[p_valid], np.array(y_valid_fold)[p_valid]

fold = "Fold0"
X_train, y_train, X_test, y_test, X_valid, y_valid = getData(fold)

# %% [markdown]
# També una funció per veure les mètriques dels models

# %%
# Plot del training loss i l'accuracy
def plot_prediction(history, description=""):
    #Plots 
    fig, ax = plt.subplots(nrows=2, ncols=3, figsize=(20,5))
    
    # F1
    zipped_train = zip(history.history['precision'], history.history['recall'])
    f1_score_train = [2 * x * y /(x + y + deltaZero) for (x, y) in zipped_train]

    zipped_test = zip(history.history['val_precision'], history.history['val_recall'])
    f1_score_test = [2 * x * y /(x + y + deltaZero) for (x, y) in zipped_test]
    
    plt.subplot(1,5,1)
    plt.plot(f1_score_train)
    plt.plot(f1_score_test)
    plt.title('model F1-score %s' % description)
    plt.ylabel('F1-score')
    plt.xlabel('epoch')
    ax = plt.gca()
    ax.set_ylim(bottom=0)
    plt.legend(['train', 'test'], loc='lower right')
    
    # Accuracy
    plt.subplot(1,5,2)
    plt.plot(history.history['binary_accuracy'])
    plt.plot(history.history['val_binary_accuracy'])
    plt.title('model binary_accuracy %s' % description)
    plt.ylabel('binary_accuracy')
    plt.xlabel('epoch')
    ax = plt.gca()
    ax.set_ylim(bottom=0)
    plt.legend(['train', 'test'], loc='lower right')

    # Loss
    plt.subplot(1,5,3)
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('model loss %s' % description)
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='lower left')
    ax = plt.gca()
    ax.set_ylim(bottom=0)

    # Precision
    plt.subplot(1,5,4)
    plt.plot(history.history['precision'])
    plt.plot(history.history['val_precision'])
    plt.title('model precision %s' % description)
    plt.ylabel('precision')
    plt.xlabel('epoch')
    ax = plt.gca()
    ax.set_ylim(bottom=0)
    plt.legend(['train', 'test'], loc='lower right')
    
    # Recall
    plt.subplot(1,5,5)
    plt.plot(history.history['recall'])
    plt.plot(history.history['val_recall'])
    plt.title('model recall %s' % description)
    plt.ylabel('recall')
    plt.xlabel('epoch')
    ax = plt.gca()
    ax.set_ylim(bottom=0)
    plt.legend(['train', 'test'], loc='lower right')

    
    plt.tight_layout()

# %% [markdown]
# Definim les mètriques que recollirem per a tots els models. La F1-score pot ser calcualda a partir de la precision i recall de manera que no l'afegim.

# %%
metrics = [tf.keras.metrics.Precision(name="precision"), tf.keras.metrics.Recall(name="recall"), tf.keras.metrics.BinaryAccuracy(name="binary_accuracy")]
patience=10
# Out:
# 2022-06-01 10:42:47.342522: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-01 10:42:47.449958: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-01 10:42:47.450728: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-01 10:42:47.452456: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-06-01 10:42:47.452826: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-01 10:42:47.453778: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-01 10:42:47.454649: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-01 10:42:49.533758: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-01 10:42:49.534917: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-01 10:42:49.535845: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-01 10:42:49.536708: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15403 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0

# %% [markdown]
# A la primera configuració s'entrena el model congelant totes les capes, excepte les que s'han afegit al final (model 1).

# %%
# Creem el model 1. https://github.com/alex-pelaez/M2.975.PRA---Glaucoma/tree/63e2abf392234c3218dcfe50bdd4b9c2a902adf8 
# https://keras.io/examples/vision/image_classification_efficientnet_fine_tuning/
# https://keras.io/guides/transfer_learning/
def getModel1(learning_rate, batch_size, epochs, metrics):
    n = 3 # Only for local environment

    model1 = keras.applications.EfficientNetB0(
        weights="imagenet",  # Load weights pre-trained on ImageNet.
        input_shape=img.shape,
        include_top=False,
    )  # Do not include the ImageNet classifier at the top.

    # Congelem totes les capes per a no variar cap paràmetre. Només entrenarem les capes noves.
    model1.trainable = False

    # Generem les capes de sortida de l'enunciat
    # GlobalAveragePolling2D
    x = layers.GlobalAveragePooling2D(name="avg_pool")(model1.output)

    # BatchNormalization
    x = layers.BatchNormalization()(x)

    # dropout amb probabilitat del 20%
    top_dropout_rate = 0.2
    x = layers.Dropout(top_dropout_rate, name="top_dropout")(x)

    # fully connected amb 2 sortides i funció d'activació logística ja que només tenim 2 classes mútument excloents
    outputs = layers.Dense(1, activation="sigmoid", name="pred")(x)

    # Generem el model final
    model1 = keras.Model(model1.input, outputs)

    # Ús d'Adam com a optimitzador
    optimizer = Adam(learning_rate=learning_rate)
    
    # Compilem el model
    model1.compile(optimizer=optimizer, loss="binary_crossentropy", metrics=metrics)

    #create callback per salvar el millor model
    filepath = '/kaggle/working/%s/Model1/%s_Model1_Epoch-{epoch:02d}_Loss-{val_loss:.2f}_Batch-%d_Rate-%.4f.hdf5' % (execFolder, datetime.today().strftime('%Y%m%d%H%M%S'), batch_size, learning_rate)
    checkpoint = ModelCheckpoint(filepath=filepath, 
                                monitor='val_loss',
                                verbose=verboseFit, 
                                save_best_only=True,
                                mode='min')
    
    # Callback per parar si no millorem
    earlystopping = EarlyStopping(monitor='val_loss', patience=patience)
    
    callbacks = [earlystopping,checkpoint]

    # Menys dades per l'entorn local
    X_train_aux = X_train
    y_train_aux = y_train
    X_valid_aux = X_valid
    y_valid_aux = y_valid
    
    if (localEnv):
        X_train_aux = X_train[:n]
        y_train_aux = y_train[:n]
        X_valid_aux = X_valid[:n]
        y_valid_aux = y_valid[:n]
        
    # Entrenem el model
    history = model1.fit(X_train_aux, y_train_aux, validation_data=(X_valid_aux, y_valid_aux), epochs=epochs, batch_size=batch_size, callbacks=callbacks, verbose=verboseFit)
    
    # Calculem f1-score sobre les dades de validació 
    loss, precision, recall, accuracy = model1.evaluate(X_valid, y_valid)
    f1_valid = 2 * precision * recall /(precision + recall + deltaZero)

    return history, f1_valid, model1

# %% [markdown]
# Durant les proves veiem que el Model 1 de seguida arriba al f1-score alt amb un patience de 5. Decidim pujar-lo a 10 ja que aturar l'entrenament al cap de menys de 10 èpoques ens sembla que podem perdre algun model millor.

# %%
patience = 10

# %%
# Cerca en reixeta
learning_rates = [0.01, 0.001, 0.0001]
batch_sizes = [8, 16, 32]
epochs = 75

if (localEnv):
    learning_rates = [0.01, 0.001]
    batch_sizes = [8,16] 
    epochs = 2 

results_M1=[]

if (flags_gridsearch[0]):
    for learning_rate in learning_rates:
        for batch_size in batch_sizes:
            # Generem el model amb els hiperparàmetres, el compilem, l'executem i avaluem
            print("Model amb Learning Rate: %.4f i Batch Size: %d" % (learning_rate, batch_size)) 
            history_model1, f1_model1, _ = getModel1(learning_rate, batch_size, epochs, metrics)
            results_M1.append(
                            {
                                'learning_rate':learning_rate,
                                'batch_size': batch_size,
                                'f1': f1_model1
                            }
            )
            
            # Mostrem les mètriques    
            plot_prediction(history_model1, "M1-%d-%.4f" % (batch_size, learning_rate))
            print("")

    # Mostrem els resultats
    display(pd.DataFrame(results_M1))
# Out:
# Model amb Learning Rate: 0.0100 i Batch Size: 8
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb0_notop.h5
# 16711680/16705208 [==============================] - 0s 0us/step
# 16719872/16705208 [==============================] - 0s 0us/step
# 2022-06-01 10:42:52.804850: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# 2022-06-01 10:42:58.762996: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8005
# /opt/conda/lib/python3.7/site-packages/keras/utils/generic_utils.py:497: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   category=CustomMaskWarning)
# 5/5 [==============================] - 1s 78ms/step - loss: 0.6182 - precision: 0.9474 - recall: 0.5070 - binary_accuracy: 0.7597
#
# Model amb Learning Rate: 0.0100 i Batch Size: 16
# 5/5 [==============================] - 0s 37ms/step - loss: 0.4950 - precision: 0.7917 - recall: 0.8028 - binary_accuracy: 0.8117
#
# Model amb Learning Rate: 0.0100 i Batch Size: 32
# 5/5 [==============================] - 0s 37ms/step - loss: 0.4855 - precision: 0.9273 - recall: 0.7183 - binary_accuracy: 0.8442
#
# Model amb Learning Rate: 0.0010 i Batch Size: 8
# 5/5 [==============================] - 0s 38ms/step - loss: 0.4502 - precision: 0.8909 - recall: 0.6901 - binary_accuracy: 0.8182
#
# Model amb Learning Rate: 0.0010 i Batch Size: 16
# 5/5 [==============================] - 0s 39ms/step - loss: 0.3994 - precision: 0.9259 - recall: 0.7042 - binary_accuracy: 0.8377
#
# Model amb Learning Rate: 0.0010 i Batch Size: 32
# 5/5 [==============================] - 0s 37ms/step - loss: 0.4040 - precision: 0.9074 - recall: 0.6901 - binary_accuracy: 0.8247
#
# Model amb Learning Rate: 0.0001 i Batch Size: 8
# 5/5 [==============================] - 0s 39ms/step - loss: 0.4172 - precision: 0.9091 - recall: 0.7042 - binary_accuracy: 0.8312
#
# Model amb Learning Rate: 0.0001 i Batch Size: 16
# 5/5 [==============================] - 0s 42ms/step - loss: 0.3786 - precision: 0.9245 - recall: 0.6901 - binary_accuracy: 0.8312
#
# Model amb Learning Rate: 0.0001 i Batch Size: 32
# 5/5 [==============================] - 0s 38ms/step - loss: 0.4252 - precision: 0.8846 - recall: 0.6479 - binary_accuracy: 0.7987
#    learning_rate  batch_size        f1
# 0         0.0100           8  0.660550
# 1         0.0100          16  0.797203
# 2         0.0100          32  0.809524
# 3         0.0010           8  0.777778
# 4         0.0010          16  0.800000
# 5         0.0010          32  0.784000
# 6         0.0001           8  0.793651
# 7         0.0001          16  0.790323
# 8         0.0001          32  0.747967

# %% [markdown]
# Observem que els millors hiperparàmetres son per a learning_rate=0.01 i batch_size=16. Mirem el fitxer on està guardat el model i el carreguem. També establim els hiperparàmetres

# %%
model1_filepath = "/kaggle/working/20220531192249_Model1_Epoch-01_Loss-0.99_Batch-8_Rate-0.0100.hdf5"
learning_rate = 0.001
batch_size = 8
epochs = 75
patience = 10

if (localEnv):
    epochs=2

if (flags_model[0]):
    # Generem el model de nou
    history_model1, _, model1 = getModel1(learning_rate, batch_size, epochs, metrics)
    
    # Mostrem les mètriques    
    plot_prediction(history_model1, "M1-%d-%.4f" % (batch_size, learning_rate))
# Out:
# /opt/conda/lib/python3.7/site-packages/keras/utils/generic_utils.py:497: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   category=CustomMaskWarning)
# 5/5 [==============================] - 0s 38ms/step - loss: 0.3964 - precision: 0.9091 - recall: 0.7042 - binary_accuracy: 0.8312

# %% [markdown]
# Veiem com la funció de pèrdua no evolucionava i per tant la condició d'aturada ha funcionat.
#
# Observem que tenim un bon classificador amb un f1-score per sobre de 0.75 per a test. També observem que la precisió i la sensitivitat tenen comportaments diferents sent el la precisió superior en el conjunt de test que en el conjunt d'entrenament i posiblement sigui degut a que és un classificador esbiaixat.
#
# Mirem la matriu de confusió i veiem que en els casos positius (abnormals) som capaços d'identificar molts dels casos però per contra observem que tenim molts falsos positius.
#
# Passem ara a generar el model 2 on:
# * Inicialitzem amb els pesos del Model 1
# * Fem servir els mateixos hiperparàmetres
# * Descongelem les darreres 20 capes

# %%
# Funció per retornar el model 2
def getModel2(model, learning_rate, batch_size, epochs):
    # We unfreeze the top 20 layers while leaving BatchNorm layers frozen
    for layer in model.layers[-20:]:
        if not isinstance(layer, layers.BatchNormalization):
            layer.trainable = True

    # Ús d'Adam com a optimitzador
    optimizer = Adam(learning_rate=learning_rate)
    
    # Compilem el model
    model.compile(optimizer=optimizer, loss="binary_crossentropy", metrics=metrics)

    #create callback per salvar el millor model
    filepath = '/kaggle/working/%s/Model2/%s_Model2_Epoch-{epoch:02d}_Loss-{val_loss:.2f}_Batch-%d_Rate-%.4f.hdf5' % (execFolder, datetime.today().strftime('%Y%m%d%H%M%S'), batch_size, learning_rate)
    checkpoint = ModelCheckpoint(filepath=filepath, 
                                monitor='val_loss',
                                verbose=verboseFit, 
                                save_best_only=True,
                                mode='min')
    
    # Callback per parar si no millorem
    earlystopping = EarlyStopping(monitor='val_loss', patience=patience)
    
    callbacks = [earlystopping,checkpoint]

    # Menys dades per l'entorn local
    X_train_aux = X_train
    y_train_aux = y_train
    X_valid_aux = X_valid
    y_valid_aux = y_valid
    
    if (localEnv):
        X_train_aux = X_train[:n]
        y_train_aux = y_train[:n]
        X_valid_aux = X_valid[:n]
        y_valid_aux = y_valid[:n]
        
    # Entrenem el model
    history = model.fit(X_train_aux, y_train_aux, validation_data=(X_valid_aux, y_valid_aux), epochs=epochs, batch_size=batch_size, callbacks=callbacks) # Remove
    
    # Calculem f1-score sobre les dades de validació 
    loss, precision, recall, accuracy = model.evaluate(X_valid, y_valid)
    f1_valid = 2 * precision * recall /(precision + recall + deltaZero)

    return history, f1_valid, model


if (flags_model[1]):
    history_model2, f1_model2, model2 = getModel2(model1, learning_rate, batch_size, epochs)

    # Mostrem les mètriques    
    plot_prediction(history_model2, "M2-%d-%.4f" % (batch_size, learning_rate))
# Out:
# Epoch 1/75
# 173/173 [==============================] - 11s 32ms/step - loss: 0.7872 - precision: 0.7269 - recall: 0.7112 - binary_accuracy: 0.7476 - val_loss: 0.5866 - val_precision: 0.8197 - val_recall: 0.7042 - val_binary_accuracy: 0.7922
# Epoch 2/75
# 173/173 [==============================] - 4s 20ms/step - loss: 0.4722 - precision: 0.7797 - recall: 0.7872 - binary_accuracy: 0.8028 - val_loss: 0.6141 - val_precision: 0.9348 - val_recall: 0.6056 - val_binary_accuracy: 0.7987
# Epoch 3/75
# 173/173 [==============================] - 4s 22ms/step - loss: 0.4189 - precision: 0.8196 - recall: 0.8144 - binary_accuracy: 0.8347 - val_loss: 1.6102 - val_precision: 0.5111 - val_recall: 0.9718 - val_binary_accuracy: 0.5584
# Epoch 4/75
# 173/173 [==============================] - 3s 20ms/step - loss: 0.4212 - precision: 0.8084 - recall: 0.7968 - binary_accuracy: 0.8223 - val_loss: 0.4317 - val_precision: 0.8308 - val_recall: 0.7606 - val_binary_accuracy: 0.8182
# Epoch 5/75
# 173/173 [==============================] - 3s 20ms/step - loss: 0.3626 - precision: 0.8317 - recall: 0.8144 - binary_accuracy: 0.8412 - val_loss: 0.3465 - val_precision: 0.8052 - val_recall: 0.8732 - val_binary_accuracy: 0.8442
# Epoch 6/75
# 173/173 [==============================] - 4s 21ms/step - loss: 0.3333 - precision: 0.8484 - recall: 0.8416 - binary_accuracy: 0.8600 - val_loss: 0.4499 - val_precision: 0.8947 - val_recall: 0.7183 - val_binary_accuracy: 0.8312
# Epoch 7/75
# 173/173 [==============================] - 3s 20ms/step - loss: 0.3384 - precision: 0.8481 - recall: 0.8400 - binary_accuracy: 0.8593 - val_loss: 0.4248 - val_precision: 0.9286 - val_recall: 0.7324 - val_binary_accuracy: 0.8506
# Epoch 8/75
# 173/173 [==============================] - 3s 20ms/step - loss: 0.2830 - precision: 0.8703 - recall: 0.8800 - binary_accuracy: 0.8861 - val_loss: 0.3171 - val_precision: 0.8267 - val_recall: 0.8732 - val_binary_accuracy: 0.8571
# Epoch 9/75
# 173/173 [==============================] - 4s 24ms/step - loss: 0.2846 - precision: 0.8574 - recall: 0.8656 - binary_accuracy: 0.8738 - val_loss: 0.5164 - val_precision: 0.9744 - val_recall: 0.5352 - val_binary_accuracy: 0.7792
# Epoch 10/75
# 173/173 [==============================] - 3s 20ms/step - loss: 0.2790 - precision: 0.8805 - recall: 0.8720 - binary_accuracy: 0.8883 - val_loss: 0.6673 - val_precision: 0.9730 - val_recall: 0.5070 - val_binary_accuracy: 0.7662
# Epoch 11/75
# 173/173 [==============================] - 3s 20ms/step - loss: 0.2327 - precision: 0.8960 - recall: 0.8960 - binary_accuracy: 0.9057 - val_loss: 0.4756 - val_precision: 1.0000 - val_recall: 0.6197 - val_binary_accuracy: 0.8247
# Epoch 12/75
# 173/173 [==============================] - 4s 21ms/step - loss: 0.2168 - precision: 0.9065 - recall: 0.9152 - binary_accuracy: 0.9188 - val_loss: 0.5537 - val_precision: 0.9750 - val_recall: 0.5493 - val_binary_accuracy: 0.7857
# Epoch 13/75
# 173/173 [==============================] - 3s 20ms/step - loss: 0.2485 - precision: 0.8909 - recall: 0.8752 - binary_accuracy: 0.8949 - val_loss: 0.7756 - val_precision: 0.9756 - val_recall: 0.5634 - val_binary_accuracy: 0.7922
# Epoch 14/75
# 173/173 [==============================] - 4s 20ms/step - loss: 0.2115 - precision: 0.8947 - recall: 0.8976 - binary_accuracy: 0.9057 - val_loss: 0.3516 - val_precision: 0.8286 - val_recall: 0.8169 - val_binary_accuracy: 0.8377
# Epoch 15/75
# 173/173 [==============================] - 4s 22ms/step - loss: 0.2085 - precision: 0.9206 - recall: 0.9088 - binary_accuracy: 0.9231 - val_loss: 0.5181 - val_precision: 0.6765 - val_recall: 0.9718 - val_binary_accuracy: 0.7727
# Epoch 16/75
# 173/173 [==============================] - 3s 20ms/step - loss: 0.1684 - precision: 0.9165 - recall: 0.9312 - binary_accuracy: 0.9304 - val_loss: 0.9248 - val_precision: 0.8451 - val_recall: 0.8451 - val_binary_accuracy: 0.8571
# Epoch 17/75
# 173/173 [==============================] - 4s 20ms/step - loss: 0.1970 - precision: 0.9267 - recall: 0.9104 - binary_accuracy: 0.9268 - val_loss: 0.5098 - val_precision: 0.9388 - val_recall: 0.6479 - val_binary_accuracy: 0.8182
# Epoch 18/75
# 173/173 [==============================] - 4s 24ms/step - loss: 0.1921 - precision: 0.9248 - recall: 0.9248 - binary_accuracy: 0.9318 - val_loss: 0.3570 - val_precision: 0.9194 - val_recall: 0.8028 - val_binary_accuracy: 0.8766
# 5/5 [==============================] - 0s 36ms/step - loss: 0.3570 - precision: 0.9194 - recall: 0.8028 - binary_accuracy: 0.8766

# %% [markdown]
# Passem ara a generar el model 3 on:
# * Inicialitzem amb els pesos del Model 2
# * Fem servir els mateixos hiperparàmetres
# * Descongelem totes les capes

# %%
# Funció per retornar el model 3
def getModel3(model, learning_rate, batch_size, epochs):
    # We unfreeze the top 20 layers while leaving BatchNorm layers frozen
    for layer in model.layers:
        if not isinstance(layer, layers.BatchNormalization):
            layer.trainable = True

    # Ús d'Adam com a optimitzador
    optimizer = Adam(learning_rate=learning_rate)
    
    # Compilem el model
    model.compile(optimizer=optimizer, loss="binary_crossentropy", metrics=metrics)

    #create callback per salvar el millor model
    filepath = '/kaggle/working/%s/Model3/%s_Model3_Epoch-{epoch:02d}_Loss-{val_loss:.2f}_Batch-%d_Rate-%.4f.hdf5' % (execFolder, datetime.today().strftime('%Y%m%d%H%M%S'), batch_size, learning_rate)
    checkpoint = ModelCheckpoint(filepath=filepath, 
                                monitor='val_loss',
                                verbose=verboseFit, 
                                save_best_only=True,
                                mode='min')
    
    # Callback per parar si no millorem
    earlystopping = EarlyStopping(monitor='val_loss', patience=patience)
    
    callbacks = [earlystopping,checkpoint]

    # Menys dades per l'entorn local
    X_train_aux = X_train
    y_train_aux = y_train
    X_valid_aux = X_valid
    y_valid_aux = y_valid
    
    if (localEnv):
        X_train_aux = X_train[:n]
        y_train_aux = y_train[:n]
        X_valid_aux = X_valid[:n]
        y_valid_aux = y_valid[:n]
        
    # Entrenem el model
    history = model.fit(X_train_aux, y_train_aux, validation_data=(X_valid_aux, y_valid_aux), epochs=epochs, batch_size=batch_size, callbacks=callbacks) # Remove
    
    # Calculem f1-score sobre les dades de validació 
    loss, precision, recall, accuracy = model.evaluate(X_valid, y_valid)
    f1_valid = 2 * precision * recall /(precision + recall + deltaZero)

    return history, f1_valid, model


if (flags_model[2]):
    history_model3, f1_model3, model3 = getModel3(model2, learning_rate, batch_size, epochs)

    # Mostrem les mètriques    
    plot_prediction(history_model3, "M3-%d-%.4f" % (batch_size, learning_rate))
# Out:
# Epoch 1/75
# 173/173 [==============================] - 24s 92ms/step - loss: 0.8954 - precision: 0.5159 - recall: 0.4425 - binary_accuracy: 0.5584 - val_loss: 4.5894 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_binary_accuracy: 0.5390
# Epoch 2/75
# 173/173 [==============================] - 15s 86ms/step - loss: 0.7841 - precision: 0.4406 - recall: 0.3680 - binary_accuracy: 0.5018 - val_loss: 0.6905 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_binary_accuracy: 0.5390
# Epoch 3/75
# 173/173 [==============================] - 14s 83ms/step - loss: 0.7715 - precision: 0.4526 - recall: 0.3744 - binary_accuracy: 0.5112 - val_loss: 0.8614 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_binary_accuracy: 0.5390
# Epoch 4/75
# 173/173 [==============================] - 15s 85ms/step - loss: 0.7403 - precision: 0.4752 - recall: 0.4144 - binary_accuracy: 0.5272 - val_loss: 0.7175 - val_precision: 0.4610 - val_recall: 1.0000 - val_binary_accuracy: 0.4610
# Epoch 5/75
# 173/173 [==============================] - 14s 83ms/step - loss: 0.7545 - precision: 0.4416 - recall: 0.3632 - binary_accuracy: 0.5033 - val_loss: 0.7126 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_binary_accuracy: 0.5390
# Epoch 6/75
# 173/173 [==============================] - 15s 85ms/step - loss: 0.7440 - precision: 0.4454 - recall: 0.3328 - binary_accuracy: 0.5098 - val_loss: 0.6911 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_binary_accuracy: 0.5390
# Epoch 7/75
# 173/173 [==============================] - 14s 83ms/step - loss: 0.7526 - precision: 0.4675 - recall: 0.3680 - binary_accuracy: 0.5236 - val_loss: 0.6989 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_binary_accuracy: 0.5390
# Epoch 8/75
# 173/173 [==============================] - 15s 84ms/step - loss: 0.7498 - precision: 0.4427 - recall: 0.3584 - binary_accuracy: 0.5047 - val_loss: 0.7184 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_binary_accuracy: 0.5390
# Epoch 9/75
# 173/173 [==============================] - 15s 86ms/step - loss: 0.7393 - precision: 0.4529 - recall: 0.3536 - binary_accuracy: 0.5134 - val_loss: 0.7321 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_binary_accuracy: 0.5390
# Epoch 10/75
# 173/173 [==============================] - 15s 84ms/step - loss: 0.7412 - precision: 0.4197 - recall: 0.3136 - binary_accuracy: 0.4924 - val_loss: 0.7156 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_binary_accuracy: 0.5390
# Epoch 11/75
# 173/173 [==============================] - 15s 86ms/step - loss: 0.7557 - precision: 0.4442 - recall: 0.3376 - binary_accuracy: 0.5083 - val_loss: 0.7053 - val_precision: 0.4610 - val_recall: 1.0000 - val_binary_accuracy: 0.4610
# Epoch 12/75
# 173/173 [==============================] - 14s 84ms/step - loss: 0.7631 - precision: 0.4525 - recall: 0.3888 - binary_accuracy: 0.5098 - val_loss: 0.7067 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_binary_accuracy: 0.5390
# 5/5 [==============================] - 0s 39ms/step - loss: 0.7067 - precision: 0.0000e+00 - recall: 0.0000e+00 - binary_accuracy: 0.5390

# %% [markdown]
# Pel model 4 farem servir EfficientNet B1 amb la mateixa configuració que al model 1 i també farem una cerca en reixeta per a trobar els millors hiperparàmetres

# %%
def getModel4(learning_rate, batch_size, epochs, metrics):
    n = 3 # Only for local environment

    model1 = keras.applications.EfficientNetB1(
        weights="imagenet",  # Load weights pre-trained on ImageNet.
        input_shape=img.shape,
        include_top=False,
    )  # Do not include the ImageNet classifier at the top.

    # Congelem totes les capes per a no variar cap paràmetre. Només entrenarem les capes noves.
    model1.trainable = False

    # Generem les capes de sortida de l'enunciat
    # GlobalAveragePolling2D
    x = layers.GlobalAveragePooling2D(name="avg_pool")(model1.output)

    # BatchNormalization
    x = layers.BatchNormalization()(x)

    # dropout amb probabilitat del 20%
    top_dropout_rate = 0.2
    x = layers.Dropout(top_dropout_rate, name="top_dropout")(x)

    # fully connected amb 2 sortides i funció d'activació logística ja que només tenim 2 classes mútument excloents
    outputs = layers.Dense(1, activation="sigmoid", name="pred")(x)

    # Generem el model final
    model1 = keras.Model(model1.input, outputs)

    # Ús d'Adam com a optimitzador
    optimizer = Adam(learning_rate=learning_rate)
    
    # Compilem el model
    model1.compile(optimizer=optimizer, loss="binary_crossentropy", metrics=metrics)

    #create callback per salvar el millor model
    filepath = '/kaggle/working/%s/Model4/%s_Model4_Epoch-{epoch:02d}_Loss-{val_loss:.2f}_Batch-%d_Rate-%.4f.hdf5' % (execFolder, datetime.today().strftime('%Y%m%d%H%M%S'), batch_size, learning_rate)
    checkpoint = ModelCheckpoint(filepath=filepath, 
                                monitor='val_loss',
                                verbose=1, 
                                save_best_only=True,
                                mode='min')
    
    # Callback per parar si no millorem en 5 èpoques
    earlystopping = EarlyStopping(monitor='val_loss', patience=patience)
    
    callbacks = [earlystopping,checkpoint]

    # Menys dades per l'entorn local
    X_train_aux = X_train
    y_train_aux = y_train
    X_valid_aux = X_valid
    y_valid_aux = y_valid
    
    if (localEnv):
        X_train_aux = X_train[:n]
        y_train_aux = y_train[:n]
        X_valid_aux = X_valid[:n]
        y_valid_aux = y_valid[:n]
        
    # Entrenem el model
    history = model1.fit(X_train_aux, y_train_aux, validation_data=(X_valid_aux, y_valid_aux), epochs=epochs, batch_size=batch_size, callbacks=callbacks, verbose=verboseFit)
    
    # Calculem f1-score sobre les dades de validació 
    loss, precision, recall, accuracy = model1.evaluate(X_valid, y_valid)
    f1_valid = 2 * precision * recall /(precision + recall + deltaZero)

    return history, f1_valid, model1

# Cerca ne reixeta
learning_rates = [0.01, 0.001, 0.0001]
batch_sizes = [8, 16, 32]
epochs = 75

if (localEnv):
    learning_rates = [0.01, 0.001]
    batch_sizes = [8,16] 
    epochs = 2 

results_M4=[]

if (flags_gridsearch[3]):
    for learning_rate in learning_rates:
        for batch_size in batch_sizes:
            # Generem el model amb els hiperparàmetres, el compilem, l'executem i avaluem
            print("Model amb Learning Rate: %.4f i Batch Size: %d" % (learning_rate, batch_size)) 
            history_model4, f1_model4, _ = getModel4(learning_rate, batch_size, epochs, metrics)
            results_M4.append(
                            {
                                'learning_rate':learning_rate,
                                'batch_size': batch_size,
                                'f1': f1_model4
                            }
            )
            plot_prediction(history_model4, "M4-%d-%.4f" % (batch_size, learning_rate))
            print("")

        # Mostrem els resultats
        display(pd.DataFrame(results_M4))
# Out:
# Model amb Learning Rate: 0.0100 i Batch Size: 8
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb1_notop.h5
# 27025408/27018416 [==============================] - 1s 0us/step
# 27033600/27018416 [==============================] - 1s 0us/step
#
# Epoch 00001: val_loss improved from inf to 0.54248, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601110556_Model4_Epoch-01_Loss-0.54_Batch-8_Rate-0.0100.hdf5
#
# Epoch 00002: val_loss improved from 0.54248 to 0.52880, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601110556_Model4_Epoch-02_Loss-0.53_Batch-8_Rate-0.0100.hdf5
#
# Epoch 00003: val_loss did not improve from 0.52880
#
# Epoch 00004: val_loss did not improve from 0.52880
#
# Epoch 00005: val_loss improved from 0.52880 to 0.52721, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601110556_Model4_Epoch-05_Loss-0.53_Batch-8_Rate-0.0100.hdf5
#
# Epoch 00006: val_loss did not improve from 0.52721
#
# Epoch 00007: val_loss improved from 0.52721 to 0.45685, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601110556_Model4_Epoch-07_Loss-0.46_Batch-8_Rate-0.0100.hdf5
#
# Epoch 00008: val_loss did not improve from 0.45685
#
# Epoch 00009: val_loss did not improve from 0.45685
#
# Epoch 00010: val_loss improved from 0.45685 to 0.39038, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601110556_Model4_Epoch-10_Loss-0.39_Batch-8_Rate-0.0100.hdf5
#
# Epoch 00011: val_loss did not improve from 0.39038
#
# Epoch 00012: val_loss did not improve from 0.39038
#
# Epoch 00013: val_loss did not improve from 0.39038
#
# Epoch 00014: val_loss did not improve from 0.39038
#
# Epoch 00015: val_loss did not improve from 0.39038
#
# Epoch 00016: val_loss did not improve from 0.39038
#
# Epoch 00017: val_loss did not improve from 0.39038
#
# Epoch 00018: val_loss did not improve from 0.39038
#
# Epoch 00019: val_loss did not improve from 0.39038
#
# Epoch 00020: val_loss did not improve from 0.39038
# 5/5 [==============================] - 0s 62ms/step - loss: 0.5012 - precision: 0.9070 - recall: 0.5493 - binary_accuracy: 0.7662
#
# Model amb Learning Rate: 0.0100 i Batch Size: 16
#
# Epoch 00001: val_loss improved from inf to 0.44204, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601110729_Model4_Epoch-01_Loss-0.44_Batch-16_Rate-0.0100.hdf5
#
# Epoch 00002: val_loss did not improve from 0.44204
#
# Epoch 00003: val_loss improved from 0.44204 to 0.41461, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601110729_Model4_Epoch-03_Loss-0.41_Batch-16_Rate-0.0100.hdf5
#
# Epoch 00004: val_loss did not improve from 0.41461
#
# Epoch 00005: val_loss did not improve from 0.41461
#
# Epoch 00006: val_loss improved from 0.41461 to 0.40199, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601110729_Model4_Epoch-06_Loss-0.40_Batch-16_Rate-0.0100.hdf5
#
# Epoch 00007: val_loss did not improve from 0.40199
#
# Epoch 00008: val_loss improved from 0.40199 to 0.37657, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601110729_Model4_Epoch-08_Loss-0.38_Batch-16_Rate-0.0100.hdf5
#
# Epoch 00009: val_loss did not improve from 0.37657
#
# Epoch 00010: val_loss did not improve from 0.37657
#
# Epoch 00011: val_loss did not improve from 0.37657
#
# Epoch 00012: val_loss did not improve from 0.37657
#
# Epoch 00013: val_loss did not improve from 0.37657
#
# Epoch 00014: val_loss did not improve from 0.37657
#
# Epoch 00015: val_loss did not improve from 0.37657
#
# Epoch 00016: val_loss did not improve from 0.37657
#
# Epoch 00017: val_loss did not improve from 0.37657
#
# Epoch 00018: val_loss did not improve from 0.37657
# 5/5 [==============================] - 0s 49ms/step - loss: 0.5739 - precision: 0.9762 - recall: 0.5775 - binary_accuracy: 0.7987
#
# Model amb Learning Rate: 0.0100 i Batch Size: 32
#
# Epoch 00001: val_loss improved from inf to 0.56062, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601110836_Model4_Epoch-01_Loss-0.56_Batch-32_Rate-0.0100.hdf5
#
# Epoch 00002: val_loss improved from 0.56062 to 0.51054, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601110836_Model4_Epoch-02_Loss-0.51_Batch-32_Rate-0.0100.hdf5
#
# Epoch 00003: val_loss improved from 0.51054 to 0.46997, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601110836_Model4_Epoch-03_Loss-0.47_Batch-32_Rate-0.0100.hdf5
#
# Epoch 00004: val_loss did not improve from 0.46997
#
# Epoch 00005: val_loss improved from 0.46997 to 0.41553, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601110836_Model4_Epoch-05_Loss-0.42_Batch-32_Rate-0.0100.hdf5
#
# Epoch 00006: val_loss did not improve from 0.41553
#
# Epoch 00007: val_loss did not improve from 0.41553
#
# Epoch 00008: val_loss did not improve from 0.41553
#
# Epoch 00009: val_loss improved from 0.41553 to 0.39507, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601110836_Model4_Epoch-09_Loss-0.40_Batch-32_Rate-0.0100.hdf5
#
# Epoch 00010: val_loss did not improve from 0.39507
#
# Epoch 00011: val_loss did not improve from 0.39507
#
# Epoch 00012: val_loss did not improve from 0.39507
#
# Epoch 00013: val_loss did not improve from 0.39507
#
# Epoch 00014: val_loss did not improve from 0.39507
#
# Epoch 00015: val_loss did not improve from 0.39507
#
# Epoch 00016: val_loss did not improve from 0.39507
#
# Epoch 00017: val_loss did not improve from 0.39507
#
# Epoch 00018: val_loss did not improve from 0.39507
#
# Epoch 00019: val_loss did not improve from 0.39507
# 5/5 [==============================] - 0s 53ms/step - loss: 0.4976 - precision: 0.8421 - recall: 0.6761 - binary_accuracy: 0.7922
#    learning_rate  batch_size        f1
# 0           0.01           8  0.684210
# 1           0.01          16  0.725664
# 2           0.01          32  0.750000
# Model amb Learning Rate: 0.0010 i Batch Size: 8
#
# Epoch 00001: val_loss improved from inf to 0.52480, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601111008_Model4_Epoch-01_Loss-0.52_Batch-8_Rate-0.0010.hdf5
# /opt/conda/lib/python3.7/site-packages/keras/utils/generic_utils.py:497: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   category=CustomMaskWarning)
# Epoch 00002: val_loss improved from 0.52480 to 0.44505, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601111008_Model4_Epoch-02_Loss-0.45_Batch-8_Rate-0.0010.hdf5
#
# Epoch 00003: val_loss improved from 0.44505 to 0.42547, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601111008_Model4_Epoch-03_Loss-0.43_Batch-8_Rate-0.0010.hdf5
#
# Epoch 00004: val_loss did not improve from 0.42547
#
# Epoch 00005: val_loss improved from 0.42547 to 0.41176, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601111008_Model4_Epoch-05_Loss-0.41_Batch-8_Rate-0.0010.hdf5
#
# Epoch 00006: val_loss did not improve from 0.41176
#
# Epoch 00007: val_loss did not improve from 0.41176
#
# Epoch 00008: val_loss improved from 0.41176 to 0.35775, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601111008_Model4_Epoch-08_Loss-0.36_Batch-8_Rate-0.0010.hdf5
#
# Epoch 00009: val_loss did not improve from 0.35775
#
# Epoch 00010: val_loss improved from 0.35775 to 0.35427, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601111008_Model4_Epoch-10_Loss-0.35_Batch-8_Rate-0.0010.hdf5
#
# Epoch 00011: val_loss did not improve from 0.35427
#
# Epoch 00012: val_loss did not improve from 0.35427
#
# Epoch 00013: val_loss did not improve from 0.35427
#
# Epoch 00014: val_loss did not improve from 0.35427
#
# Epoch 00015: val_loss did not improve from 0.35427
#
# Epoch 00016: val_loss did not improve from 0.35427
#
# Epoch 00017: val_loss did not improve from 0.35427
#
# Epoch 00018: val_loss did not improve from 0.35427
#
# Epoch 00019: val_loss did not improve from 0.35427
#
# Epoch 00020: val_loss did not improve from 0.35427
# 5/5 [==============================] - 0s 50ms/step - loss: 0.3932 - precision: 0.8980 - recall: 0.6197 - binary_accuracy: 0.7922
#
# Model amb Learning Rate: 0.0010 i Batch Size: 16
#
# Epoch 00001: val_loss improved from inf to 0.53451, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601111141_Model4_Epoch-01_Loss-0.53_Batch-16_Rate-0.0010.hdf5
#
# Epoch 00002: val_loss improved from 0.53451 to 0.47978, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601111141_Model4_Epoch-02_Loss-0.48_Batch-16_Rate-0.0010.hdf5
#
# Epoch 00003: val_loss improved from 0.47978 to 0.43309, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601111141_Model4_Epoch-03_Loss-0.43_Batch-16_Rate-0.0010.hdf5
#
# Epoch 00004: val_loss improved from 0.43309 to 0.41646, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601111141_Model4_Epoch-04_Loss-0.42_Batch-16_Rate-0.0010.hdf5
#
# Epoch 00005: val_loss improved from 0.41646 to 0.40966, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601111141_Model4_Epoch-05_Loss-0.41_Batch-16_Rate-0.0010.hdf5
#
# Epoch 00006: val_loss did not improve from 0.40966
#
# Epoch 00007: val_loss improved from 0.40966 to 0.39740, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601111141_Model4_Epoch-07_Loss-0.40_Batch-16_Rate-0.0010.hdf5
#
# Epoch 00008: val_loss did not improve from 0.39740
#
# Epoch 00009: val_loss improved from 0.39740 to 0.39211, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601111141_Model4_Epoch-09_Loss-0.39_Batch-16_Rate-0.0010.hdf5
#
# Epoch 00010: val_loss did not improve from 0.39211
#
# Epoch 00011: val_loss did not improve from 0.39211
#
# Epoch 00012: val_loss improved from 0.39211 to 0.38794, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601111141_Model4_Epoch-12_Loss-0.39_Batch-16_Rate-0.0010.hdf5
#
# Epoch 00013: val_loss improved from 0.38794 to 0.38109, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601111141_Model4_Epoch-13_Loss-0.38_Batch-16_Rate-0.0010.hdf5
#
# Epoch 00014: val_loss improved from 0.38109 to 0.36233, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601111141_Model4_Epoch-14_Loss-0.36_Batch-16_Rate-0.0010.hdf5
#
# Epoch 00015: val_loss did not improve from 0.36233
#
# Epoch 00016: val_loss did not improve from 0.36233
#
# Epoch 00017: val_loss did not improve from 0.36233
#
# Epoch 00018: val_loss did not improve from 0.36233
#
# Epoch 00019: val_loss did not improve from 0.36233
#
# Epoch 00020: val_loss did not improve from 0.36233
#
# Epoch 00021: val_loss did not improve from 0.36233
#
# Epoch 00022: val_loss did not improve from 0.36233
#
# Epoch 00023: val_loss did not improve from 0.36233
#
# Epoch 00024: val_loss did not improve from 0.36233
# 5/5 [==============================] - 0s 52ms/step - loss: 0.4002 - precision: 0.8929 - recall: 0.7042 - binary_accuracy: 0.8247
#
# Model amb Learning Rate: 0.0010 i Batch Size: 32
#
# Epoch 00001: val_loss improved from inf to 0.55192, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601111313_Model4_Epoch-01_Loss-0.55_Batch-32_Rate-0.0010.hdf5
#
# Epoch 00002: val_loss improved from 0.55192 to 0.50594, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601111313_Model4_Epoch-02_Loss-0.51_Batch-32_Rate-0.0010.hdf5
#
# Epoch 00003: val_loss improved from 0.50594 to 0.48191, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601111313_Model4_Epoch-03_Loss-0.48_Batch-32_Rate-0.0010.hdf5
#
# Epoch 00004: val_loss improved from 0.48191 to 0.46215, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601111313_Model4_Epoch-04_Loss-0.46_Batch-32_Rate-0.0010.hdf5
#
# Epoch 00005: val_loss improved from 0.46215 to 0.43904, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601111313_Model4_Epoch-05_Loss-0.44_Batch-32_Rate-0.0010.hdf5
#
# Epoch 00006: val_loss improved from 0.43904 to 0.42893, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601111313_Model4_Epoch-06_Loss-0.43_Batch-32_Rate-0.0010.hdf5
#
# Epoch 00007: val_loss improved from 0.42893 to 0.42013, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601111313_Model4_Epoch-07_Loss-0.42_Batch-32_Rate-0.0010.hdf5
#
# Epoch 00008: val_loss improved from 0.42013 to 0.41157, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601111313_Model4_Epoch-08_Loss-0.41_Batch-32_Rate-0.0010.hdf5
#
# Epoch 00009: val_loss improved from 0.41157 to 0.39127, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601111313_Model4_Epoch-09_Loss-0.39_Batch-32_Rate-0.0010.hdf5
#
# Epoch 00010: val_loss improved from 0.39127 to 0.39101, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601111313_Model4_Epoch-10_Loss-0.39_Batch-32_Rate-0.0010.hdf5
#
# Epoch 00011: val_loss improved from 0.39101 to 0.39073, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601111313_Model4_Epoch-11_Loss-0.39_Batch-32_Rate-0.0010.hdf5
#
# Epoch 00012: val_loss improved from 0.39073 to 0.37675, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601111313_Model4_Epoch-12_Loss-0.38_Batch-32_Rate-0.0010.hdf5
#
# Epoch 00013: val_loss improved from 0.37675 to 0.37344, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601111313_Model4_Epoch-13_Loss-0.37_Batch-32_Rate-0.0010.hdf5
#
# Epoch 00014: val_loss did not improve from 0.37344
#
# Epoch 00015: val_loss did not improve from 0.37344
#
# Epoch 00016: val_loss improved from 0.37344 to 0.36533, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601111313_Model4_Epoch-16_Loss-0.37_Batch-32_Rate-0.0010.hdf5
#
# Epoch 00017: val_loss improved from 0.36533 to 0.36483, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601111313_Model4_Epoch-17_Loss-0.36_Batch-32_Rate-0.0010.hdf5
#
# Epoch 00018: val_loss improved from 0.36483 to 0.36146, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601111313_Model4_Epoch-18_Loss-0.36_Batch-32_Rate-0.0010.hdf5
#
# Epoch 00019: val_loss improved from 0.36146 to 0.35809, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601111313_Model4_Epoch-19_Loss-0.36_Batch-32_Rate-0.0010.hdf5
#
# Epoch 00020: val_loss did not improve from 0.35809
#
# Epoch 00021: val_loss improved from 0.35809 to 0.35346, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601111313_Model4_Epoch-21_Loss-0.35_Batch-32_Rate-0.0010.hdf5
#
# Epoch 00022: val_loss improved from 0.35346 to 0.34834, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601111313_Model4_Epoch-22_Loss-0.35_Batch-32_Rate-0.0010.hdf5
#
# Epoch 00023: val_loss did not improve from 0.34834
#
# Epoch 00024: val_loss did not improve from 0.34834
#
# Epoch 00025: val_loss did not improve from 0.34834
#
# Epoch 00026: val_loss did not improve from 0.34834
#
# Epoch 00027: val_loss improved from 0.34834 to 0.34833, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601111313_Model4_Epoch-27_Loss-0.35_Batch-32_Rate-0.0010.hdf5
#
# Epoch 00028: val_loss did not improve from 0.34833
#
# Epoch 00029: val_loss did not improve from 0.34833
#
# Epoch 00030: val_loss did not improve from 0.34833
#
# Epoch 00031: val_loss improved from 0.34833 to 0.34230, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601111313_Model4_Epoch-31_Loss-0.34_Batch-32_Rate-0.0010.hdf5
#
# Epoch 00032: val_loss improved from 0.34230 to 0.33961, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601111313_Model4_Epoch-32_Loss-0.34_Batch-32_Rate-0.0010.hdf5
#
# Epoch 00033: val_loss did not improve from 0.33961
#
# Epoch 00034: val_loss did not improve from 0.33961
#
# Epoch 00035: val_loss did not improve from 0.33961
#
# Epoch 00036: val_loss did not improve from 0.33961
#
# Epoch 00037: val_loss did not improve from 0.33961
#
# Epoch 00038: val_loss did not improve from 0.33961
#
# Epoch 00039: val_loss did not improve from 0.33961
#
# Epoch 00040: val_loss did not improve from 0.33961
#
# Epoch 00041: val_loss did not improve from 0.33961
#
# Epoch 00042: val_loss did not improve from 0.33961
# 5/5 [==============================] - 0s 56ms/step - loss: 0.3579 - precision: 0.9412 - recall: 0.6761 - binary_accuracy: 0.8312
#    learning_rate  batch_size        f1
# 0          0.010           8  0.684210
# 1          0.010          16  0.725664
# 2          0.010          32  0.750000
# 3          0.001           8  0.733333
# 4          0.001          16  0.787402
# 5          0.001          32  0.786885
# Model amb Learning Rate: 0.0001 i Batch Size: 8
#
# Epoch 00001: val_loss improved from inf to 0.57498, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601111519_Model4_Epoch-01_Loss-0.57_Batch-8_Rate-0.0001.hdf5
# /opt/conda/lib/python3.7/site-packages/keras/utils/generic_utils.py:497: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   category=CustomMaskWarning)
# Epoch 00002: val_loss improved from 0.57498 to 0.51893, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601111519_Model4_Epoch-02_Loss-0.52_Batch-8_Rate-0.0001.hdf5
#
# Epoch 00003: val_loss improved from 0.51893 to 0.50023, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601111519_Model4_Epoch-03_Loss-0.50_Batch-8_Rate-0.0001.hdf5
#
# Epoch 00004: val_loss improved from 0.50023 to 0.49301, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601111519_Model4_Epoch-04_Loss-0.49_Batch-8_Rate-0.0001.hdf5
#
# Epoch 00005: val_loss improved from 0.49301 to 0.48421, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601111519_Model4_Epoch-05_Loss-0.48_Batch-8_Rate-0.0001.hdf5
#
# Epoch 00006: val_loss improved from 0.48421 to 0.47711, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601111519_Model4_Epoch-06_Loss-0.48_Batch-8_Rate-0.0001.hdf5
#
# Epoch 00007: val_loss improved from 0.47711 to 0.46853, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601111519_Model4_Epoch-07_Loss-0.47_Batch-8_Rate-0.0001.hdf5
#
# Epoch 00008: val_loss improved from 0.46853 to 0.46146, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601111519_Model4_Epoch-08_Loss-0.46_Batch-8_Rate-0.0001.hdf5
#
# Epoch 00009: val_loss improved from 0.46146 to 0.45902, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601111519_Model4_Epoch-09_Loss-0.46_Batch-8_Rate-0.0001.hdf5
#
# Epoch 00010: val_loss improved from 0.45902 to 0.45211, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601111519_Model4_Epoch-10_Loss-0.45_Batch-8_Rate-0.0001.hdf5
#
# Epoch 00011: val_loss improved from 0.45211 to 0.44607, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601111519_Model4_Epoch-11_Loss-0.45_Batch-8_Rate-0.0001.hdf5
#
# Epoch 00012: val_loss improved from 0.44607 to 0.44240, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601111519_Model4_Epoch-12_Loss-0.44_Batch-8_Rate-0.0001.hdf5
#
# Epoch 00013: val_loss improved from 0.44240 to 0.44077, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601111519_Model4_Epoch-13_Loss-0.44_Batch-8_Rate-0.0001.hdf5
#
# Epoch 00014: val_loss improved from 0.44077 to 0.43803, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601111519_Model4_Epoch-14_Loss-0.44_Batch-8_Rate-0.0001.hdf5
#
# Epoch 00015: val_loss improved from 0.43803 to 0.43669, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601111519_Model4_Epoch-15_Loss-0.44_Batch-8_Rate-0.0001.hdf5
#
# Epoch 00016: val_loss improved from 0.43669 to 0.43062, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601111519_Model4_Epoch-16_Loss-0.43_Batch-8_Rate-0.0001.hdf5
#
# Epoch 00017: val_loss improved from 0.43062 to 0.42768, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601111519_Model4_Epoch-17_Loss-0.43_Batch-8_Rate-0.0001.hdf5
#
# Epoch 00018: val_loss improved from 0.42768 to 0.42437, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601111519_Model4_Epoch-18_Loss-0.42_Batch-8_Rate-0.0001.hdf5
#
# Epoch 00019: val_loss did not improve from 0.42437
#
# Epoch 00020: val_loss improved from 0.42437 to 0.41916, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601111519_Model4_Epoch-20_Loss-0.42_Batch-8_Rate-0.0001.hdf5
#
# Epoch 00021: val_loss did not improve from 0.41916
#
# Epoch 00022: val_loss improved from 0.41916 to 0.41429, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601111519_Model4_Epoch-22_Loss-0.41_Batch-8_Rate-0.0001.hdf5
#
# Epoch 00023: val_loss did not improve from 0.41429
#
# Epoch 00024: val_loss improved from 0.41429 to 0.41261, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601111519_Model4_Epoch-24_Loss-0.41_Batch-8_Rate-0.0001.hdf5
#
# Epoch 00025: val_loss improved from 0.41261 to 0.40793, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601111519_Model4_Epoch-25_Loss-0.41_Batch-8_Rate-0.0001.hdf5
#
# Epoch 00026: val_loss did not improve from 0.40793
#
# Epoch 00027: val_loss improved from 0.40793 to 0.40491, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601111519_Model4_Epoch-27_Loss-0.40_Batch-8_Rate-0.0001.hdf5
#
# Epoch 00028: val_loss did not improve from 0.40491
#
# Epoch 00029: val_loss improved from 0.40491 to 0.40265, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601111519_Model4_Epoch-29_Loss-0.40_Batch-8_Rate-0.0001.hdf5
#
# Epoch 00030: val_loss improved from 0.40265 to 0.39654, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601111519_Model4_Epoch-30_Loss-0.40_Batch-8_Rate-0.0001.hdf5
#
# Epoch 00031: val_loss did not improve from 0.39654
#
# Epoch 00032: val_loss did not improve from 0.39654
#
# Epoch 00033: val_loss improved from 0.39654 to 0.39635, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601111519_Model4_Epoch-33_Loss-0.40_Batch-8_Rate-0.0001.hdf5
#
# Epoch 00034: val_loss improved from 0.39635 to 0.39563, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601111519_Model4_Epoch-34_Loss-0.40_Batch-8_Rate-0.0001.hdf5
#
# Epoch 00035: val_loss improved from 0.39563 to 0.39125, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601111519_Model4_Epoch-35_Loss-0.39_Batch-8_Rate-0.0001.hdf5
#
# Epoch 00036: val_loss did not improve from 0.39125
#
# Epoch 00037: val_loss did not improve from 0.39125
#
# Epoch 00038: val_loss did not improve from 0.39125
#
# Epoch 00039: val_loss did not improve from 0.39125
#
# Epoch 00040: val_loss did not improve from 0.39125
#
# Epoch 00041: val_loss did not improve from 0.39125
#
# Epoch 00042: val_loss improved from 0.39125 to 0.38839, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601111519_Model4_Epoch-42_Loss-0.39_Batch-8_Rate-0.0001.hdf5
#
# Epoch 00043: val_loss improved from 0.38839 to 0.38707, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601111519_Model4_Epoch-43_Loss-0.39_Batch-8_Rate-0.0001.hdf5
#
# Epoch 00044: val_loss did not improve from 0.38707
#
# Epoch 00045: val_loss did not improve from 0.38707
#
# Epoch 00046: val_loss improved from 0.38707 to 0.38510, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601111519_Model4_Epoch-46_Loss-0.39_Batch-8_Rate-0.0001.hdf5
#
# Epoch 00047: val_loss improved from 0.38510 to 0.38187, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601111519_Model4_Epoch-47_Loss-0.38_Batch-8_Rate-0.0001.hdf5
#
# Epoch 00048: val_loss improved from 0.38187 to 0.37941, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601111519_Model4_Epoch-48_Loss-0.38_Batch-8_Rate-0.0001.hdf5
#
# Epoch 00049: val_loss improved from 0.37941 to 0.37833, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601111519_Model4_Epoch-49_Loss-0.38_Batch-8_Rate-0.0001.hdf5
#
# Epoch 00050: val_loss did not improve from 0.37833
#
# Epoch 00051: val_loss did not improve from 0.37833
#
# Epoch 00052: val_loss improved from 0.37833 to 0.37474, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601111519_Model4_Epoch-52_Loss-0.37_Batch-8_Rate-0.0001.hdf5
#
# Epoch 00053: val_loss improved from 0.37474 to 0.37277, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601111519_Model4_Epoch-53_Loss-0.37_Batch-8_Rate-0.0001.hdf5
#
# Epoch 00054: val_loss improved from 0.37277 to 0.37271, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601111519_Model4_Epoch-54_Loss-0.37_Batch-8_Rate-0.0001.hdf5
#
# Epoch 00055: val_loss did not improve from 0.37271
#
# Epoch 00056: val_loss did not improve from 0.37271
#
# Epoch 00057: val_loss improved from 0.37271 to 0.37040, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601111519_Model4_Epoch-57_Loss-0.37_Batch-8_Rate-0.0001.hdf5
#
# Epoch 00058: val_loss did not improve from 0.37040
#
# Epoch 00059: val_loss did not improve from 0.37040
#
# Epoch 00060: val_loss did not improve from 0.37040
#
# Epoch 00061: val_loss did not improve from 0.37040
#
# Epoch 00062: val_loss did not improve from 0.37040
#
# Epoch 00063: val_loss improved from 0.37040 to 0.36995, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601111519_Model4_Epoch-63_Loss-0.37_Batch-8_Rate-0.0001.hdf5
#
# Epoch 00064: val_loss did not improve from 0.36995
#
# Epoch 00065: val_loss did not improve from 0.36995
#
# Epoch 00066: val_loss improved from 0.36995 to 0.36548, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601111519_Model4_Epoch-66_Loss-0.37_Batch-8_Rate-0.0001.hdf5
#
# Epoch 00067: val_loss did not improve from 0.36548
#
# Epoch 00068: val_loss did not improve from 0.36548
#
# Epoch 00069: val_loss did not improve from 0.36548
#
# Epoch 00070: val_loss did not improve from 0.36548
#
# Epoch 00071: val_loss improved from 0.36548 to 0.36448, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601111519_Model4_Epoch-71_Loss-0.36_Batch-8_Rate-0.0001.hdf5
#
# Epoch 00072: val_loss did not improve from 0.36448
#
# Epoch 00073: val_loss did not improve from 0.36448
#
# Epoch 00074: val_loss did not improve from 0.36448
#
# Epoch 00075: val_loss did not improve from 0.36448
# 5/5 [==============================] - 0s 59ms/step - loss: 0.3646 - precision: 0.8846 - recall: 0.6479 - binary_accuracy: 0.7987
#
# Model amb Learning Rate: 0.0001 i Batch Size: 16
#
# Epoch 00001: val_loss improved from inf to 0.69553, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601112052_Model4_Epoch-01_Loss-0.70_Batch-16_Rate-0.0001.hdf5
#
# Epoch 00002: val_loss improved from 0.69553 to 0.62383, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601112052_Model4_Epoch-02_Loss-0.62_Batch-16_Rate-0.0001.hdf5
#
# Epoch 00003: val_loss improved from 0.62383 to 0.56534, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601112052_Model4_Epoch-03_Loss-0.57_Batch-16_Rate-0.0001.hdf5
#
# Epoch 00004: val_loss improved from 0.56534 to 0.52091, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601112052_Model4_Epoch-04_Loss-0.52_Batch-16_Rate-0.0001.hdf5
#
# Epoch 00005: val_loss improved from 0.52091 to 0.49348, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601112052_Model4_Epoch-05_Loss-0.49_Batch-16_Rate-0.0001.hdf5
#
# Epoch 00006: val_loss improved from 0.49348 to 0.47617, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601112052_Model4_Epoch-06_Loss-0.48_Batch-16_Rate-0.0001.hdf5
#
# Epoch 00007: val_loss improved from 0.47617 to 0.46400, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601112052_Model4_Epoch-07_Loss-0.46_Batch-16_Rate-0.0001.hdf5
#
# Epoch 00008: val_loss improved from 0.46400 to 0.45676, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601112052_Model4_Epoch-08_Loss-0.46_Batch-16_Rate-0.0001.hdf5
#
# Epoch 00009: val_loss improved from 0.45676 to 0.44645, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601112052_Model4_Epoch-09_Loss-0.45_Batch-16_Rate-0.0001.hdf5
#
# Epoch 00010: val_loss improved from 0.44645 to 0.44202, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601112052_Model4_Epoch-10_Loss-0.44_Batch-16_Rate-0.0001.hdf5
#
# Epoch 00011: val_loss improved from 0.44202 to 0.43734, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601112052_Model4_Epoch-11_Loss-0.44_Batch-16_Rate-0.0001.hdf5
#
# Epoch 00012: val_loss improved from 0.43734 to 0.43458, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601112052_Model4_Epoch-12_Loss-0.43_Batch-16_Rate-0.0001.hdf5
#
# Epoch 00013: val_loss improved from 0.43458 to 0.43371, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601112052_Model4_Epoch-13_Loss-0.43_Batch-16_Rate-0.0001.hdf5
#
# Epoch 00014: val_loss improved from 0.43371 to 0.43285, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601112052_Model4_Epoch-14_Loss-0.43_Batch-16_Rate-0.0001.hdf5
#
# Epoch 00015: val_loss improved from 0.43285 to 0.43094, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601112052_Model4_Epoch-15_Loss-0.43_Batch-16_Rate-0.0001.hdf5
#
# Epoch 00016: val_loss improved from 0.43094 to 0.42805, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601112052_Model4_Epoch-16_Loss-0.43_Batch-16_Rate-0.0001.hdf5
#
# Epoch 00017: val_loss improved from 0.42805 to 0.42710, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601112052_Model4_Epoch-17_Loss-0.43_Batch-16_Rate-0.0001.hdf5
#
# Epoch 00018: val_loss improved from 0.42710 to 0.42151, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601112052_Model4_Epoch-18_Loss-0.42_Batch-16_Rate-0.0001.hdf5
#
# Epoch 00019: val_loss improved from 0.42151 to 0.42113, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601112052_Model4_Epoch-19_Loss-0.42_Batch-16_Rate-0.0001.hdf5
#
# Epoch 00020: val_loss did not improve from 0.42113
#
# Epoch 00021: val_loss improved from 0.42113 to 0.41811, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601112052_Model4_Epoch-21_Loss-0.42_Batch-16_Rate-0.0001.hdf5
#
# Epoch 00022: val_loss did not improve from 0.41811
#
# Epoch 00023: val_loss improved from 0.41811 to 0.41500, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601112052_Model4_Epoch-23_Loss-0.42_Batch-16_Rate-0.0001.hdf5
#
# Epoch 00024: val_loss improved from 0.41500 to 0.41285, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601112052_Model4_Epoch-24_Loss-0.41_Batch-16_Rate-0.0001.hdf5
#
# Epoch 00025: val_loss improved from 0.41285 to 0.41184, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601112052_Model4_Epoch-25_Loss-0.41_Batch-16_Rate-0.0001.hdf5
#
# Epoch 00026: val_loss improved from 0.41184 to 0.41154, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601112052_Model4_Epoch-26_Loss-0.41_Batch-16_Rate-0.0001.hdf5
#
# Epoch 00027: val_loss improved from 0.41154 to 0.40641, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601112052_Model4_Epoch-27_Loss-0.41_Batch-16_Rate-0.0001.hdf5
#
# Epoch 00028: val_loss improved from 0.40641 to 0.40448, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601112052_Model4_Epoch-28_Loss-0.40_Batch-16_Rate-0.0001.hdf5
#
# Epoch 00029: val_loss did not improve from 0.40448
#
# Epoch 00030: val_loss improved from 0.40448 to 0.40266, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601112052_Model4_Epoch-30_Loss-0.40_Batch-16_Rate-0.0001.hdf5
#
# Epoch 00031: val_loss improved from 0.40266 to 0.40029, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601112052_Model4_Epoch-31_Loss-0.40_Batch-16_Rate-0.0001.hdf5
#
# Epoch 00032: val_loss improved from 0.40029 to 0.39899, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601112052_Model4_Epoch-32_Loss-0.40_Batch-16_Rate-0.0001.hdf5
#
# Epoch 00033: val_loss did not improve from 0.39899
#
# Epoch 00034: val_loss improved from 0.39899 to 0.39457, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601112052_Model4_Epoch-34_Loss-0.39_Batch-16_Rate-0.0001.hdf5
#
# Epoch 00035: val_loss did not improve from 0.39457
#
# Epoch 00036: val_loss improved from 0.39457 to 0.39254, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601112052_Model4_Epoch-36_Loss-0.39_Batch-16_Rate-0.0001.hdf5
#
# Epoch 00037: val_loss did not improve from 0.39254
#
# Epoch 00038: val_loss did not improve from 0.39254
#
# Epoch 00039: val_loss did not improve from 0.39254
#
# Epoch 00040: val_loss did not improve from 0.39254
#
# Epoch 00041: val_loss did not improve from 0.39254
#
# Epoch 00042: val_loss improved from 0.39254 to 0.39204, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601112052_Model4_Epoch-42_Loss-0.39_Batch-16_Rate-0.0001.hdf5
#
# Epoch 00043: val_loss improved from 0.39204 to 0.38650, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601112052_Model4_Epoch-43_Loss-0.39_Batch-16_Rate-0.0001.hdf5
#
# Epoch 00044: val_loss did not improve from 0.38650
#
# Epoch 00045: val_loss did not improve from 0.38650
#
# Epoch 00046: val_loss improved from 0.38650 to 0.38623, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601112052_Model4_Epoch-46_Loss-0.39_Batch-16_Rate-0.0001.hdf5
#
# Epoch 00047: val_loss improved from 0.38623 to 0.38276, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601112052_Model4_Epoch-47_Loss-0.38_Batch-16_Rate-0.0001.hdf5
#
# Epoch 00048: val_loss did not improve from 0.38276
#
# Epoch 00049: val_loss did not improve from 0.38276
#
# Epoch 00050: val_loss improved from 0.38276 to 0.38256, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601112052_Model4_Epoch-50_Loss-0.38_Batch-16_Rate-0.0001.hdf5
#
# Epoch 00051: val_loss improved from 0.38256 to 0.37839, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601112052_Model4_Epoch-51_Loss-0.38_Batch-16_Rate-0.0001.hdf5
#
# Epoch 00052: val_loss did not improve from 0.37839
#
# Epoch 00053: val_loss did not improve from 0.37839
#
# Epoch 00054: val_loss did not improve from 0.37839
#
# Epoch 00055: val_loss improved from 0.37839 to 0.37663, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601112052_Model4_Epoch-55_Loss-0.38_Batch-16_Rate-0.0001.hdf5
#
# Epoch 00056: val_loss improved from 0.37663 to 0.37497, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601112052_Model4_Epoch-56_Loss-0.37_Batch-16_Rate-0.0001.hdf5
#
# Epoch 00057: val_loss improved from 0.37497 to 0.37085, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601112052_Model4_Epoch-57_Loss-0.37_Batch-16_Rate-0.0001.hdf5
#
# Epoch 00058: val_loss improved from 0.37085 to 0.37042, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601112052_Model4_Epoch-58_Loss-0.37_Batch-16_Rate-0.0001.hdf5
#
# Epoch 00059: val_loss improved from 0.37042 to 0.37002, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601112052_Model4_Epoch-59_Loss-0.37_Batch-16_Rate-0.0001.hdf5
#
# Epoch 00060: val_loss did not improve from 0.37002
#
# Epoch 00061: val_loss improved from 0.37002 to 0.37001, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601112052_Model4_Epoch-61_Loss-0.37_Batch-16_Rate-0.0001.hdf5
#
# Epoch 00062: val_loss improved from 0.37001 to 0.36985, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601112052_Model4_Epoch-62_Loss-0.37_Batch-16_Rate-0.0001.hdf5
#
# Epoch 00063: val_loss improved from 0.36985 to 0.36867, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601112052_Model4_Epoch-63_Loss-0.37_Batch-16_Rate-0.0001.hdf5
#
# Epoch 00064: val_loss did not improve from 0.36867
#
# Epoch 00065: val_loss did not improve from 0.36867
#
# Epoch 00066: val_loss improved from 0.36867 to 0.36660, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601112052_Model4_Epoch-66_Loss-0.37_Batch-16_Rate-0.0001.hdf5
#
# Epoch 00067: val_loss did not improve from 0.36660
#
# Epoch 00068: val_loss did not improve from 0.36660
#
# Epoch 00069: val_loss did not improve from 0.36660
#
# Epoch 00070: val_loss did not improve from 0.36660
#
# Epoch 00071: val_loss did not improve from 0.36660
#
# Epoch 00072: val_loss improved from 0.36660 to 0.36616, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601112052_Model4_Epoch-72_Loss-0.37_Batch-16_Rate-0.0001.hdf5
#
# Epoch 00073: val_loss did not improve from 0.36616
#
# Epoch 00074: val_loss improved from 0.36616 to 0.36522, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601112052_Model4_Epoch-74_Loss-0.37_Batch-16_Rate-0.0001.hdf5
#
# Epoch 00075: val_loss improved from 0.36522 to 0.36465, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601112052_Model4_Epoch-75_Loss-0.36_Batch-16_Rate-0.0001.hdf5
# 5/5 [==============================] - 0s 53ms/step - loss: 0.3646 - precision: 0.8519 - recall: 0.6479 - binary_accuracy: 0.7857
#
# Model amb Learning Rate: 0.0001 i Batch Size: 32
#
# Epoch 00001: val_loss improved from inf to 0.66923, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601112525_Model4_Epoch-01_Loss-0.67_Batch-32_Rate-0.0001.hdf5
#
# Epoch 00002: val_loss improved from 0.66923 to 0.63475, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601112525_Model4_Epoch-02_Loss-0.63_Batch-32_Rate-0.0001.hdf5
#
# Epoch 00003: val_loss improved from 0.63475 to 0.60625, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601112525_Model4_Epoch-03_Loss-0.61_Batch-32_Rate-0.0001.hdf5
#
# Epoch 00004: val_loss improved from 0.60625 to 0.57878, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601112525_Model4_Epoch-04_Loss-0.58_Batch-32_Rate-0.0001.hdf5
#
# Epoch 00005: val_loss improved from 0.57878 to 0.55502, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601112525_Model4_Epoch-05_Loss-0.56_Batch-32_Rate-0.0001.hdf5
#
# Epoch 00006: val_loss improved from 0.55502 to 0.53166, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601112525_Model4_Epoch-06_Loss-0.53_Batch-32_Rate-0.0001.hdf5
#
# Epoch 00007: val_loss improved from 0.53166 to 0.51346, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601112525_Model4_Epoch-07_Loss-0.51_Batch-32_Rate-0.0001.hdf5
#
# Epoch 00008: val_loss improved from 0.51346 to 0.49639, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601112525_Model4_Epoch-08_Loss-0.50_Batch-32_Rate-0.0001.hdf5
#
# Epoch 00009: val_loss improved from 0.49639 to 0.48446, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601112525_Model4_Epoch-09_Loss-0.48_Batch-32_Rate-0.0001.hdf5
#
# Epoch 00010: val_loss improved from 0.48446 to 0.47567, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601112525_Model4_Epoch-10_Loss-0.48_Batch-32_Rate-0.0001.hdf5
#
# Epoch 00011: val_loss improved from 0.47567 to 0.47034, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601112525_Model4_Epoch-11_Loss-0.47_Batch-32_Rate-0.0001.hdf5
#
# Epoch 00012: val_loss improved from 0.47034 to 0.46352, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601112525_Model4_Epoch-12_Loss-0.46_Batch-32_Rate-0.0001.hdf5
#
# Epoch 00013: val_loss improved from 0.46352 to 0.46051, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601112525_Model4_Epoch-13_Loss-0.46_Batch-32_Rate-0.0001.hdf5
#
# Epoch 00014: val_loss improved from 0.46051 to 0.46036, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601112525_Model4_Epoch-14_Loss-0.46_Batch-32_Rate-0.0001.hdf5
#
# Epoch 00015: val_loss improved from 0.46036 to 0.45812, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601112525_Model4_Epoch-15_Loss-0.46_Batch-32_Rate-0.0001.hdf5
#
# Epoch 00016: val_loss improved from 0.45812 to 0.45381, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601112525_Model4_Epoch-16_Loss-0.45_Batch-32_Rate-0.0001.hdf5
#
# Epoch 00017: val_loss improved from 0.45381 to 0.45095, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601112525_Model4_Epoch-17_Loss-0.45_Batch-32_Rate-0.0001.hdf5
#
# Epoch 00018: val_loss improved from 0.45095 to 0.44704, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601112525_Model4_Epoch-18_Loss-0.45_Batch-32_Rate-0.0001.hdf5
#
# Epoch 00019: val_loss did not improve from 0.44704
#
# Epoch 00020: val_loss improved from 0.44704 to 0.44287, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601112525_Model4_Epoch-20_Loss-0.44_Batch-32_Rate-0.0001.hdf5
#
# Epoch 00021: val_loss improved from 0.44287 to 0.44158, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601112525_Model4_Epoch-21_Loss-0.44_Batch-32_Rate-0.0001.hdf5
#
# Epoch 00022: val_loss improved from 0.44158 to 0.43927, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601112525_Model4_Epoch-22_Loss-0.44_Batch-32_Rate-0.0001.hdf5
#
# Epoch 00023: val_loss improved from 0.43927 to 0.43900, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601112525_Model4_Epoch-23_Loss-0.44_Batch-32_Rate-0.0001.hdf5
#
# Epoch 00024: val_loss did not improve from 0.43900
#
# Epoch 00025: val_loss improved from 0.43900 to 0.43763, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601112525_Model4_Epoch-25_Loss-0.44_Batch-32_Rate-0.0001.hdf5
#
# Epoch 00026: val_loss did not improve from 0.43763
#
# Epoch 00027: val_loss improved from 0.43763 to 0.43381, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601112525_Model4_Epoch-27_Loss-0.43_Batch-32_Rate-0.0001.hdf5
#
# Epoch 00028: val_loss did not improve from 0.43381
#
# Epoch 00029: val_loss did not improve from 0.43381
#
# Epoch 00030: val_loss did not improve from 0.43381
#
# Epoch 00031: val_loss improved from 0.43381 to 0.42876, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601112525_Model4_Epoch-31_Loss-0.43_Batch-32_Rate-0.0001.hdf5
#
# Epoch 00032: val_loss improved from 0.42876 to 0.42498, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601112525_Model4_Epoch-32_Loss-0.42_Batch-32_Rate-0.0001.hdf5
#
# Epoch 00033: val_loss improved from 0.42498 to 0.42376, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601112525_Model4_Epoch-33_Loss-0.42_Batch-32_Rate-0.0001.hdf5
#
# Epoch 00034: val_loss improved from 0.42376 to 0.42336, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601112525_Model4_Epoch-34_Loss-0.42_Batch-32_Rate-0.0001.hdf5
#
# Epoch 00035: val_loss did not improve from 0.42336
#
# Epoch 00036: val_loss improved from 0.42336 to 0.42061, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601112525_Model4_Epoch-36_Loss-0.42_Batch-32_Rate-0.0001.hdf5
#
# Epoch 00037: val_loss did not improve from 0.42061
#
# Epoch 00038: val_loss improved from 0.42061 to 0.41927, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601112525_Model4_Epoch-38_Loss-0.42_Batch-32_Rate-0.0001.hdf5
#
# Epoch 00039: val_loss improved from 0.41927 to 0.41904, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601112525_Model4_Epoch-39_Loss-0.42_Batch-32_Rate-0.0001.hdf5
#
# Epoch 00040: val_loss improved from 0.41904 to 0.41596, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601112525_Model4_Epoch-40_Loss-0.42_Batch-32_Rate-0.0001.hdf5
#
# Epoch 00041: val_loss improved from 0.41596 to 0.41570, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601112525_Model4_Epoch-41_Loss-0.42_Batch-32_Rate-0.0001.hdf5
#
# Epoch 00042: val_loss did not improve from 0.41570
#
# Epoch 00043: val_loss improved from 0.41570 to 0.41353, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601112525_Model4_Epoch-43_Loss-0.41_Batch-32_Rate-0.0001.hdf5
#
# Epoch 00044: val_loss improved from 0.41353 to 0.41341, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601112525_Model4_Epoch-44_Loss-0.41_Batch-32_Rate-0.0001.hdf5
#
# Epoch 00045: val_loss improved from 0.41341 to 0.41341, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601112525_Model4_Epoch-45_Loss-0.41_Batch-32_Rate-0.0001.hdf5
#
# Epoch 00046: val_loss improved from 0.41341 to 0.41163, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601112525_Model4_Epoch-46_Loss-0.41_Batch-32_Rate-0.0001.hdf5
#
# Epoch 00047: val_loss did not improve from 0.41163
#
# Epoch 00048: val_loss improved from 0.41163 to 0.41040, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601112525_Model4_Epoch-48_Loss-0.41_Batch-32_Rate-0.0001.hdf5
#
# Epoch 00049: val_loss improved from 0.41040 to 0.40918, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601112525_Model4_Epoch-49_Loss-0.41_Batch-32_Rate-0.0001.hdf5
#
# Epoch 00050: val_loss improved from 0.40918 to 0.40790, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601112525_Model4_Epoch-50_Loss-0.41_Batch-32_Rate-0.0001.hdf5
#
# Epoch 00051: val_loss improved from 0.40790 to 0.40605, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601112525_Model4_Epoch-51_Loss-0.41_Batch-32_Rate-0.0001.hdf5
#
# Epoch 00052: val_loss improved from 0.40605 to 0.40567, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601112525_Model4_Epoch-52_Loss-0.41_Batch-32_Rate-0.0001.hdf5
#
# Epoch 00053: val_loss improved from 0.40567 to 0.40354, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601112525_Model4_Epoch-53_Loss-0.40_Batch-32_Rate-0.0001.hdf5
#
# Epoch 00054: val_loss did not improve from 0.40354
#
# Epoch 00055: val_loss did not improve from 0.40354
#
# Epoch 00056: val_loss improved from 0.40354 to 0.40247, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601112525_Model4_Epoch-56_Loss-0.40_Batch-32_Rate-0.0001.hdf5
#
# Epoch 00057: val_loss improved from 0.40247 to 0.40240, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601112525_Model4_Epoch-57_Loss-0.40_Batch-32_Rate-0.0001.hdf5
#
# Epoch 00058: val_loss did not improve from 0.40240
#
# Epoch 00059: val_loss did not improve from 0.40240
#
# Epoch 00060: val_loss did not improve from 0.40240
#
# Epoch 00061: val_loss improved from 0.40240 to 0.40051, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601112525_Model4_Epoch-61_Loss-0.40_Batch-32_Rate-0.0001.hdf5
#
# Epoch 00062: val_loss improved from 0.40051 to 0.39971, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601112525_Model4_Epoch-62_Loss-0.40_Batch-32_Rate-0.0001.hdf5
#
# Epoch 00063: val_loss improved from 0.39971 to 0.39950, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601112525_Model4_Epoch-63_Loss-0.40_Batch-32_Rate-0.0001.hdf5
#
# Epoch 00064: val_loss improved from 0.39950 to 0.39665, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601112525_Model4_Epoch-64_Loss-0.40_Batch-32_Rate-0.0001.hdf5
#
# Epoch 00065: val_loss did not improve from 0.39665
#
# Epoch 00066: val_loss did not improve from 0.39665
#
# Epoch 00067: val_loss did not improve from 0.39665
#
# Epoch 00068: val_loss improved from 0.39665 to 0.39522, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601112525_Model4_Epoch-68_Loss-0.40_Batch-32_Rate-0.0001.hdf5
#
# Epoch 00069: val_loss improved from 0.39522 to 0.39500, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601112525_Model4_Epoch-69_Loss-0.39_Batch-32_Rate-0.0001.hdf5
#
# Epoch 00070: val_loss did not improve from 0.39500
#
# Epoch 00071: val_loss did not improve from 0.39500
#
# Epoch 00072: val_loss improved from 0.39500 to 0.39071, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601112525_Model4_Epoch-72_Loss-0.39_Batch-32_Rate-0.0001.hdf5
#
# Epoch 00073: val_loss improved from 0.39071 to 0.38984, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601112525_Model4_Epoch-73_Loss-0.39_Batch-32_Rate-0.0001.hdf5
#
# Epoch 00074: val_loss did not improve from 0.38984
#
# Epoch 00075: val_loss improved from 0.38984 to 0.38829, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601112525_Model4_Epoch-75_Loss-0.39_Batch-32_Rate-0.0001.hdf5
# 5/5 [==============================] - 0s 50ms/step - loss: 0.3883 - precision: 0.8846 - recall: 0.6479 - binary_accuracy: 0.7987
#    learning_rate  batch_size        f1
# 0         0.0100           8  0.684210
# 1         0.0100          16  0.725664
# 2         0.0100          32  0.750000
# 3         0.0010           8  0.733333
# 4         0.0010          16  0.787402
# 5         0.0010          32  0.786885
# 6         0.0001           8  0.747967
# 7         0.0001          16  0.736000
# 8         0.0001          32  0.747967

# %%
# Millors hiperparàmetres per a model 4
learning_rate = 0.001
batch_size = 32
epochs = 75
patience = 5

if (localEnv):
    epochs=2

if (flags_model[3]):
    # Generem el model de nou
    history_model4, _, model4 = getModel4(learning_rate, batch_size, epochs, metrics)

    # Mostrem les mètriques
    plot_prediction(history_model4, "M4-%d-%.4f" % (batch_size, learning_rate))
# Out:
# Epoch 00001: val_loss improved from inf to 0.57617, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601112917_Model4_Epoch-01_Loss-0.58_Batch-32_Rate-0.0010.hdf5
# /opt/conda/lib/python3.7/site-packages/keras/utils/generic_utils.py:497: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   category=CustomMaskWarning)
# Epoch 00002: val_loss improved from 0.57617 to 0.52504, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601112917_Model4_Epoch-02_Loss-0.53_Batch-32_Rate-0.0010.hdf5
#
# Epoch 00003: val_loss improved from 0.52504 to 0.49738, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601112917_Model4_Epoch-03_Loss-0.50_Batch-32_Rate-0.0010.hdf5
#
# Epoch 00004: val_loss improved from 0.49738 to 0.47976, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601112917_Model4_Epoch-04_Loss-0.48_Batch-32_Rate-0.0010.hdf5
#
# Epoch 00005: val_loss improved from 0.47976 to 0.46859, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601112917_Model4_Epoch-05_Loss-0.47_Batch-32_Rate-0.0010.hdf5
#
# Epoch 00006: val_loss improved from 0.46859 to 0.43341, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601112917_Model4_Epoch-06_Loss-0.43_Batch-32_Rate-0.0010.hdf5
#
# Epoch 00007: val_loss improved from 0.43341 to 0.43024, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601112917_Model4_Epoch-07_Loss-0.43_Batch-32_Rate-0.0010.hdf5
#
# Epoch 00008: val_loss improved from 0.43024 to 0.41251, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601112917_Model4_Epoch-08_Loss-0.41_Batch-32_Rate-0.0010.hdf5
#
# Epoch 00009: val_loss improved from 0.41251 to 0.40296, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601112917_Model4_Epoch-09_Loss-0.40_Batch-32_Rate-0.0010.hdf5
#
# Epoch 00010: val_loss improved from 0.40296 to 0.39766, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601112917_Model4_Epoch-10_Loss-0.40_Batch-32_Rate-0.0010.hdf5
#
# Epoch 00011: val_loss did not improve from 0.39766
#
# Epoch 00012: val_loss improved from 0.39766 to 0.39042, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601112917_Model4_Epoch-12_Loss-0.39_Batch-32_Rate-0.0010.hdf5
#
# Epoch 00013: val_loss did not improve from 0.39042
#
# Epoch 00014: val_loss did not improve from 0.39042
#
# Epoch 00015: val_loss improved from 0.39042 to 0.38161, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601112917_Model4_Epoch-15_Loss-0.38_Batch-32_Rate-0.0010.hdf5
#
# Epoch 00016: val_loss improved from 0.38161 to 0.37928, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601112917_Model4_Epoch-16_Loss-0.38_Batch-32_Rate-0.0010.hdf5
#
# Epoch 00017: val_loss did not improve from 0.37928
#
# Epoch 00018: val_loss did not improve from 0.37928
#
# Epoch 00019: val_loss did not improve from 0.37928
#
# Epoch 00020: val_loss improved from 0.37928 to 0.37708, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601112917_Model4_Epoch-20_Loss-0.38_Batch-32_Rate-0.0010.hdf5
#
# Epoch 00021: val_loss did not improve from 0.37708
#
# Epoch 00022: val_loss did not improve from 0.37708
#
# Epoch 00023: val_loss improved from 0.37708 to 0.36100, saving model to /kaggle/working/EX_20220601_104231/Model4/20220601112917_Model4_Epoch-23_Loss-0.36_Batch-32_Rate-0.0010.hdf5
#
# Epoch 00024: val_loss did not improve from 0.36100
#
# Epoch 00025: val_loss did not improve from 0.36100
#
# Epoch 00026: val_loss did not improve from 0.36100
#
# Epoch 00027: val_loss did not improve from 0.36100
#
# Epoch 00028: val_loss did not improve from 0.36100
# 5/5 [==============================] - 0s 55ms/step - loss: 0.3715 - precision: 0.8772 - recall: 0.7042 - binary_accuracy: 0.8182

# %% [markdown]
# Fem el mateix per a B2

# %%
def getModel5(learning_rate, batch_size, epochs, metrics):
    n = 3 # Only for local environment

    model1 = keras.applications.EfficientNetB2(
        weights="imagenet",  # Load weights pre-trained on ImageNet.
        input_shape=img.shape,
        include_top=False,
    )  # Do not include the ImageNet classifier at the top.

    # Congelem totes les capes per a no variar cap paràmetre. Només entrenarem les capes noves.
    model1.trainable = False

    # Generem les capes de sortida de l'enunciat
    # GlobalAveragePolling2D
    x = layers.GlobalAveragePooling2D(name="avg_pool")(model1.output)

    # BatchNormalization
    x = layers.BatchNormalization()(x)

    # dropout amb probabilitat del 20%
    top_dropout_rate = 0.2
    x = layers.Dropout(top_dropout_rate, name="top_dropout")(x)

    # fully connected amb 2 sortides i funció d'activació logística ja que només tenim 2 classes mútument excloents
    outputs = layers.Dense(1, activation="sigmoid", name="pred")(x)

    # Generem el model final
    model1 = keras.Model(model1.input, outputs)

    # Ús d'Adam com a optimitzador
    optimizer = Adam(learning_rate=learning_rate)
    
    # Compilem el model
    model1.compile(optimizer=optimizer, loss="binary_crossentropy", metrics=metrics)

    #create callback per salvar el millor model
    filepath = '/kaggle/working/%s/Model5/%s_Model5_Epoch-{epoch:02d}_Loss-{val_loss:.2f}_Batch-%d_Rate-%.4f.hdf5' % (execFolder, datetime.today().strftime('%Y%m%d%H%M%S'), batch_size, learning_rate)
    checkpoint = ModelCheckpoint(filepath=filepath, 
                                monitor='val_loss',
                                verbose=verboseFit, 
                                save_best_only=True,
                                mode='min')
    
    # Callback per parar si no millorem en 5 èpoques
    earlystopping = EarlyStopping(monitor='val_loss', patience=patience)
    
    callbacks = [earlystopping,checkpoint]

    # Menys dades per l'entorn local
    X_train_aux = X_train
    y_train_aux = y_train
    X_valid_aux = X_valid
    y_valid_aux = y_valid
    
    if (localEnv):
        X_train_aux = X_train[:n]
        y_train_aux = y_train[:n]
        X_valid_aux = X_valid[:n]
        y_valid_aux = y_valid[:n]
        
    # Entrenem el model
    history = model1.fit(X_train_aux, y_train_aux, validation_data=(X_valid_aux, y_valid_aux), epochs=epochs, batch_size=batch_size, callbacks=callbacks, verbose=verboseFit) # Remove
    
    # Calculem f1-score sobre les dades de validació 
    loss, precision, recall, accuracy = model1.evaluate(X_valid, y_valid)
    f1_valid = 2 * precision * recall /(precision + recall + deltaZero)

    return history, f1_valid, model1

# Cerca ne reixeta
learning_rates = [0.01, 0.001, 0.0001]
batch_sizes = [8, 16, 32]
epochs = 75

if (localEnv):
    learning_rates = [0.01, 0.001]
    batch_sizes = [8,16] 
    epochs = 2 

results_M5=[]

if (flags_gridsearch[4]):
    for learning_rate in learning_rates:
        for batch_size in batch_sizes:
            # Generem el model amb els hiperparàmetres, el compilem, l'executem i avaluem
            #print("Model amb Learning Rate: %.4f i Batch Size: %d" % (learning_rate, batch_size)) 
            
            history_model5, f1_model5, _ = getModel5(learning_rate, batch_size, epochs, metrics)
            results_M5.append(
                            {
                                'learning_rate':learning_rate,
                                'batch_size': batch_size,
                                'f1': f1_model4
                            }
            )
            plot_prediction(history_model5, "M5-%d-%.4f" % (batch_size, learning_rate))
            #print("")

    # Mostrem els resultats
    display(pd.DataFrame(results_M5))
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb2_notop.h5
# 31793152/31790344 [==============================] - 0s 0us/step
# 31801344/31790344 [==============================] - 0s 0us/step
# 5/5 [==============================] - 1s 95ms/step - loss: 0.7052 - precision: 0.8800 - recall: 0.6197 - binary_accuracy: 0.7857
# 5/5 [==============================] - 0s 55ms/step - loss: 0.6176 - precision: 0.8393 - recall: 0.6620 - binary_accuracy: 0.7857
# 5/5 [==============================] - 0s 59ms/step - loss: 0.5149 - precision: 0.7742 - recall: 0.6761 - binary_accuracy: 0.7597
# 5/5 [==============================] - 0s 57ms/step - loss: 0.4295 - precision: 0.8627 - recall: 0.6197 - binary_accuracy: 0.7792
# 5/5 [==============================] - 0s 66ms/step - loss: 0.4104 - precision: 0.8545 - recall: 0.6620 - binary_accuracy: 0.7922
# 5/5 [==============================] - 0s 58ms/step - loss: 0.4134 - precision: 0.8980 - recall: 0.6197 - binary_accuracy: 0.7922
# 5/5 [==============================] - 0s 56ms/step - loss: 0.4366 - precision: 0.9057 - recall: 0.6761 - binary_accuracy: 0.8182
# 5/5 [==============================] - 0s 55ms/step - loss: 0.3549 - precision: 0.8793 - recall: 0.7183 - binary_accuracy: 0.8247
# 5/5 [==============================] - 0s 54ms/step - loss: 0.4062 - precision: 0.8772 - recall: 0.7042 - binary_accuracy: 0.8182
#    learning_rate  batch_size        f1
# 0         0.0100           8  0.747967
# 1         0.0100          16  0.747967
# 2         0.0100          32  0.747967
# 3         0.0010           8  0.747967
# 4         0.0010          16  0.747967
# 5         0.0010          32  0.747967
# 6         0.0001           8  0.747967
# 7         0.0001          16  0.747967
# 8         0.0001          32  0.747967

# %%
# Millors hiperparàmetres per a model 5
learning_rate = 0.0001
batch_size = 16
epochs = 75
patience = 5

if (localEnv):
    epochs=2

if (flags_model[4]):
    # Generem el model de nou
    history_model5, _, model5 = getModel5(learning_rate, batch_size, epochs, metrics)

    # Mostrem les mètriques
    plot_prediction(history_model5, "M5-%d-%.4f" % (batch_size, learning_rate))
# Out:
# /opt/conda/lib/python3.7/site-packages/keras/utils/generic_utils.py:497: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   category=CustomMaskWarning)
# 5/5 [==============================] - 0s 57ms/step - loss: 0.4218 - precision: 0.8333 - recall: 0.6338 - binary_accuracy: 0.7727

# %% [markdown]
# ## Secció 3. Validació creuada i discussió (3 punts)

# %% [markdown]
# ## Secció 4. Anàlisi crítica (1,5 punts)
#
# Idea: Podem generar imatges addicionals amb trasnformacions de color, brillantor, rotacó, mirroring
